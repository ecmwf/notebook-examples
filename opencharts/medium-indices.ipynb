# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <img src="data:image/png;base64,..." width="500px"/>
# </div>
#
# # 	Indices (MUCAPE/Kindex/Totalx)

# %% [markdown]
# This notebook will provide you guidance how to explore ECMWF data to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://apps.ecmwf.int/webapps/opencharts/products/medium-indices

# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>

# %% [markdown]
# ECMWF forecast data is available under diffrent licences for different users. To find out which licence applies to you please visit our [Use cases and licence conditions page](https://www.ecmwf.int/en/forecasts/accessing-forecasts/licences-available).
#
# To find out how to obtain the access to the ECMWF forecast data please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 4 parameters:
#
# * [Most-unstable CAPE](https://apps.ecmwf.int/codes/grib/param-db/?id=228235)
# * [K index](https://apps.ecmwf.int/codes/grib/param-db/?id=260121)
# * [Total totals index](https://apps.ecmwf.int/codes/grib/param-db/?id=260123)
# * [Mean sea level pressure](https://apps.ecmwf.int/codes/grib/param-db/?id=151)

# %% [markdown]
# In this example, we will use:
# - [**ecmwf-api-client**](https://pypi.org/project/ecmwf-api-client/) to download the data
# - [**ecmwf.data**](https://github.com/ecmwf/ecmwf-data) library to read and process the data
# - [**magpye**](https://magpye.readthedocs.io) to plot the result

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#!pip install ecmwf-data ecmwf-api-client magpye

# %%
import ecmwf.data as ecdata
from magpye import GeoMap
from ecmwfapi import *
import requests

# %%
filename = 'medium-indices.grib'

# %% [markdown]
# If you already have the access to the ECMWF archived forecast data, you can use the next cell to download data from the [MARS archive](https://confluence.ecmwf.int/display/UDOC/MARS+user+documentation):

# %%
server = ECMWFService("mars")
server.execute(
    {
    "class": "od",
    "date": "-1",
    "expver": "1",
    "levtype": "sfc",
    "param": "151/228235/260121/260123",
    "step": "12",
    "stream": "oper",
    "time": "00",
    "type": "fc",
    "grid": "0.4/0.4"
    },
    filename)

# %% [markdown]
# Alternatevly we have prepared small sample dataset to explore

# %%
url = f"https://get.ecmwf.int/repository/opencharts-sample-data/{filename}"
r = requests.get(url)
with open(filename, 'wb') as file:
    file.write(r.content)

# %% [markdown]
# ## Reading and processing the data
# Now we can use **ecmwf.data** to read the file.

# %%
data = ecdata.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>kx</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20220223</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>260121</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>msl</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20220223</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>0</td><td style='text-align: left;'>151</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>mucape</th><td style='text-align: left;'>mostUnstableParcel</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20220223</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>228235</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>totalx</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20220223</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>260123</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# And an overview of one parameter, where we can see more information, such as units or type of level.

# %%
data.describe('totalx')
# Out:
#
#                 <table>
#                 <tr></tr>
#                 <tr><th style='text-align: right;'>shortName</th><td style='text-align: left;'>totalx</td></tr><tr><th style='text-align: right;'>name</th><td style='text-align: left;'>Total totals index</td></tr><tr><th style='text-align: right;'>paramId</th><td style='text-align: left;'>260123</td></tr><tr><th style='text-align: right;'>units</th><td style='text-align: left;'>K</td></tr><tr><th style='text-align: right;'>typeOfLevel</th><td style='text-align: left;'>surface</td></tr><tr><th style='text-align: right;'>level</th><td style='text-align: left;'>0</td></tr><tr><th style='text-align: right;'>date</th><td style='text-align: left;'>20220223</td></tr><tr><th style='text-align: right;'>time</th><td style='text-align: left;'>0</td></tr><tr><th style='text-align: right;'>step</th><td style='text-align: left;'>12</td></tr><tr><th style='text-align: right;'>number</th><td style='text-align: left;'>None</td></tr><tr><th style='text-align: right;'>class</th><td style='text-align: left;'>od</td></tr><tr><th style='text-align: right;'>stream</th><td style='text-align: left;'>oper</td></tr><tr><th style='text-align: right;'>type</th><td style='text-align: left;'>fc</td></tr><tr><th style='text-align: right;'>experimentVersionNumber</th><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#         centre shortName     typeOfLevel      level  dataDate  dataTime  \
# Message
# 0        ecmf       msl              surface    0    20220223      0
# 1        ecmf    mucape   mostUnstableParcel    0    20220223      0
# 2        ecmf        kx              surface    0    20220223      0
# 3        ecmf    totalx              surface    0    20220223      0
#
#         stepRange dataType number   gridType
# Message
# 0           12       fc        0   regular_ll
# 1           12       fc     None   regular_ll
# 2           12       fc     None   regular_ll
# 3           12       fc     None   regular_ll

# %% [markdown]
# The grib file contains all the parameters, and we will use the select() function to filter what we need.

# %%
msl = data.select(shortName= 'msl')
mucape = data.select(shortName= 'mucape')
kx = data.select(shortName= 'kx')
totalx = data.select(shortName= 'totalx')

# %% [markdown]
# In our dataset the Mean sea level pressure has units Pa, but we want to plot it in hPa, so we need to divide by 100.

# %%
msl = msl / 100

# %% [markdown]
# ## Plotting the data
# And finally, we can plot the data on the map.
# First we plot MUCAPE and Mean sea level pressure.

# %%
fig = GeoMap(area_name='europe')

fig.coastlines(land_colour="cream",resolution="medium")

fig.contour_shaded(mucape, style="cape_rainbow_2")
fig.contour_lines(msl, style="black_i5")

fig.coastlines(resolution="medium")
fig.gridlines()

fig.title(["Indices: MUCAPE",
           "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H' where='shortName=msl'/> ",
           "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' where='shortName=msl'/>, STEP: <grib_info key='step' where='shortName=msl' />"])
fig.legend()
fig.footer("© European Centre for Medium-Range Weather Forecasts (ECMWF) Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use (https://apps.ecmwf.int/datasets/licences/general/)", logo='ecmwf')

fig.show()

# %% [markdown]
# Next, we plot K index and Mean sea level pressure.

# %%
fig = GeoMap(area_name='europe')

fig.coastlines(land_colour="cream",resolution="medium")

fig.contour_shaded(kx, style="kx_red")
fig.contour_lines(msl, style="black_i5")

fig.coastlines(resolution="medium")
fig.gridlines()

fig.title(["Indices: Kindex",
           "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H' where='shortName=msl'/> ",
           "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' where='shortName=msl'/>, STEP: <grib_info key='step' where='shortName=msl' />"])
fig.legend()
fig.footer("© European Centre for Medium-Range Weather Forecasts (ECMWF) Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use (https://apps.ecmwf.int/datasets/licences/general/)", logo='ecmwf')

fig.show()

# %% [markdown]
# In the end we plot the Total totals index and Mean sea level pressure.

# %%
fig = GeoMap(area_name='europe')

fig.coastlines(land_colour="cream",resolution="medium")

fig.contour_shaded(totalx, style="totalx_red")
fig.contour_lines(msl, style="black_i5")

fig.coastlines(resolution="medium")
fig.gridlines()

fig.title(["Indices: Total totals index",
           "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H' where='shortName=msl'/> ",
           "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' where='shortName=msl'/>, STEP: <grib_info key='step' where='shortName=msl' />"])
fig.legend()
fig.footer("© European Centre for Medium-Range Weather Forecasts (ECMWF) Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use (https://apps.ecmwf.int/datasets/licences/general/)", logo='ecmwf')

fig.show()

# %% [markdown]
# Note that plot produced using this dataset will slightly differ from one from Open Charts. This is due to different resolution of the data.
# The data used here is on 0.4x0.4 resolution, while high resolution data is 0.1x0.1 grid.
