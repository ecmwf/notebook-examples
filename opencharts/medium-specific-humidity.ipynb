# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>
#
# # 	Specific humidity at various pressure levels

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://apps.ecmwf.int/webapps/opencharts/products/medium-specific-humidity

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/UDOC/ECMWF+Open+Data+-+Real+Time).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 1 parameter:
#
# * [Specific humidity](https://apps.ecmwf.int/codes/grib/param-db/?id=133)

# %% [markdown]
# In this example, we will use:
# - **ecmwf.opendata** Client to download the data
# - **ecmwf.data** library to read and process the data (calculate the speed and probabilities)
# - **ecmwf.geomaps** to plot the result

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#import sys
#!{sys.executable} -m pip install ecmwf-data ecmwf-opendata git+https://github.com/ecmwf/ecmwf-geomaps.git

# %%
import ecmwf.data as ecdata
from ecmwf.geomaps import GeoMap
from ecmwf.opendata import Client

# %%
client = Client("ecmwf", beta=True)

# %%
parameters = ['q']
filename = 'medium-specific-humidity.grib'
filename
# Out:
# 'medium-specific-humidity.grib'

# %%
client.retrieve(
    date=-2,
    time=0,
    step=12,
    stream="oper",
    type="fc",
    levtype="pl",
    levelist=[1000,925,850,700,500,300,250,200,50],
    param=parameters,
    target=filename
)
# Out:
# {'date': '-2', 'time': '0', 'step': '12', 'stream': 'oper', 'type': 'fc', 'resol': '0p4-beta', '_url': 'https://ai4edataeuwest.blob.core.windows.net/ecmwf', 'extension': 'grib2'}
# {'levtype': ['pl'], 'levelist': ['1000', '925', '850', '700', '500', '300', '250', '200', '50'], 'param': ['q'], 'step': ['12'], 'type': ['fc']}

# %% [markdown]
# ## Reading and processing the data
# Now we can use **ecmwf.data** to read the file.

# %%
data = ecdata.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>q</th><td style='text-align: left;'>isobaricInhPa</td><td style='text-align: left;'>50,200,...</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>133</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#         centre shortName  typeOfLevel    level  dataDate  dataTime stepRange  \
# Message
# 0        ecmf       q     isobaricInhPa   300   20220116      0        12
# 1        ecmf       q     isobaricInhPa   925   20220116      0        12
# 2        ecmf       q     isobaricInhPa    50   20220116      0        12
# 3        ecmf       q     isobaricInhPa  1000   20220116      0        12
# 4        ecmf       q     isobaricInhPa   250   20220116      0        12
# 5        ecmf       q     isobaricInhPa   500   20220116      0        12
# 6        ecmf       q     isobaricInhPa   700   20220116      0        12
# 7        ecmf       q     isobaricInhPa   850   20220116      0        12
# 8        ecmf       q     isobaricInhPa   200   20220116      0        12
#
#         dataType number   gridType
# Message
# 0          fc     None   regular_ll
# 1          fc     None   regular_ll
# 2          fc     None   regular_ll
# 3          fc     None   regular_ll
# 4          fc     None   regular_ll
# 5          fc     None   regular_ll
# 6          fc     None   regular_ll
# 7          fc     None   regular_ll
# 8          fc     None   regular_ll

# %% [markdown]
# The grib file contains all the levels, and we will use the **select()** function to filter one of them.

# %%
q700 = data.select(level = 700)
q700.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>q</th><td style='text-align: left;'>isobaricInhPa</td><td style='text-align: left;'>700</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>None</td><td style='text-align: left;'>133</td><td style='text-align: left;'>od</td><td style='text-align: left;'>oper</td><td style='text-align: left;'>fc</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# In order to match the units in the Open charts plot, we need to multiply the data with 100000.

# %%
q700 *= 1000

# %% [markdown]
# ## Plotting the data
# And finally, we can plot the data on the map.

# %%
fig = GeoMap(area_name='europe', preset='background-foreground')

fig.contour_lines(q700, preset="sh_spechum_option1")

fig.title(["Specific humidity at various pressure levels, level <grib_info key='level' /> hPa ", 
          "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H'/> ",
          " VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' />, STEP: <grib_info key='step'/>"])
fig.legend()

fig.show()
# Out:
# Magics-warning: description is not a known keyword
