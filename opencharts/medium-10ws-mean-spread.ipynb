# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <img src="data:image/png;base64,..." width="500px"/>
# </div>
#
# # 	Ensemble mean and spread for 10m wind speed

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://apps.ecmwf.int/webapps/opencharts/products/medium-10ws-mean-spread

# %% [markdown]
# <div style="text-align: center;">
# <img src="data:image/png;base64,..."/>
# </div>

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/UDOC/ECMWF+Open+Data+-+Real+Time).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 2 parameters :
#
# * [10 metre U wind component](https://apps.ecmwf.int/codes/grib/param-db/?id=165)
# * [10 metre V wind component](https://apps.ecmwf.int/codes/grib/param-db/?id=166)

# %% [markdown]
# In this example, we will use:
# - [**ecmwf.opendata**](https://github.com/ecmwf/ecmwf-opendata) Client to download the data
# - [**ecmwf.data**](https://github.com/ecmwf/ecmwf-data) library to read and process the data
# - [**magpye**](https://magpye.readthedocs.io) to plot the result

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#!pip install ecmwf-data ecmwf-opendata magpye

# %%
import ecmwf.data as ecdata
from magpye import GeoMap
from ecmwf.opendata import Client

# %%
client = Client("ecmwf", beta=True)

# %%
parameters = ['10u','10v']
filename = 'medium-10ws-mean-spread.grib'
filename
# Out:
# 'medium-10ws-mean-spread.grib'

# %% [markdown]
# To calculate the mean and spread of the 10m wind speed, we need to retrieve all the ensemble members at the given time.
# We need to put both **cf** and **pf** as type **type** to download all 50 ensemble members as well as the control forecast.

# %% [markdown]
# Setting date to 0 will download today's data.
# Removing date and time altogether from the request will download the latest data.
# Try commenting out date and time to download latest forecast!

# %%
client.retrieve(
 date=0,
 time=0,
 step=72,
 stream="enfo",
 type=['cf', 'pf'],
 levtype="sfc",
 param=parameters,
 target=filename
)

# %% [markdown]
# ## Reading and processing the data
# Now we can use **ecmwf.data** to read the file.

# %%
data = ecdata.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>10u</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>10</td><td style='text-align: left;'>20220427</td><td style='text-align: left;'>0</td><td style='text-align: left;'>72</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>165</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>10v</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>10</td><td style='text-align: left;'>20220427</td><td style='text-align: left;'>0</td><td style='text-align: left;'>72</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>166</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.
# Note that this fieldset has all fields randomly arranged. You can see that if you look at the **number** column. These are ensemble member numbers.

# %%
data.ls()
# Out:
#         centre shortName    typeOfLevel      level  dataDate  dataTime  \
# Message
# 0        ecmf      10u    heightAboveGround   10    20220427      0
# 1        ecmf      10u    heightAboveGround   10    20220427      0
# 2        ecmf      10v    heightAboveGround   10    20220427      0
# 3        ecmf      10v    heightAboveGround   10    20220427      0
# 4        ecmf      10v    heightAboveGround   10    20220427      0
# 5        ecmf      10v    heightAboveGround   10    20220427      0
# 6        ecmf      10u    heightAboveGround   10    20220427      0
# 7        ecmf      10v    heightAboveGround   10    20220427      0
# 8        ecmf      10v    heightAboveGround   10    20220427      0
# 9        ecmf      10v    heightAboveGround   10    20220427      0
# 10       ecmf      10u    heightAboveGround   10    20220427      0
# 11       ecmf      10v    heightAboveGround   10    20220427      0
# 12       ecmf      10v    heightAboveGround   10    20220427      0
# 13       ecmf      10u    heightAboveGround   10    20220427      0
# 14       ecmf      10v    heightAboveGround   10    20220427      0
# 15       ecmf      10v    heightAboveGround   10    20220427      0
# 16       ecmf      10v    heightAboveGround   10    20220427      0
# 17       ecmf      10u    heightAboveGround   10    20220427      0
# 18       ecmf      10u    heightAboveGround   10    20220427      0
# 19       ecmf      10v    heightAboveGround   10    20220427      0
# 20       ecmf      10u    heightAboveGround   10    20220427      0
# 21       ecmf      10v    heightAboveGround   10    20220427      0
# 22       ecmf      10u    heightAboveGround   10    20220427      0
# 23       ecmf      10u    heightAboveGround   10    20220427      0
# 24       ecmf      10u    heightAboveGround   10    20220427      0
# 25       ecmf      10v    heightAboveGround   10    20220427      0
# 26       ecmf      10v    heightAboveGround   10    20220427      0
# 27       ecmf      10v    heightAboveGround   10    20220427      0
# 28       ecmf      10u    heightAboveGround   10    20220427      0
# 29       ecmf      10v    heightAboveGround   10    20220427      0
# 30       ecmf      10u    heightAboveGround   10    20220427      0
# 31       ecmf      10v    heightAboveGround   10    20220427      0
# 32       ecmf      10v    heightAboveGround   10    20220427      0
# 33       ecmf      10u    heightAboveGround   10    20220427      0
# 34       ecmf      10u    heightAboveGround   10    20220427      0
# 35       ecmf      10u    heightAboveGround   10    20220427      0
# 36       ecmf      10v    heightAboveGround   10    20220427      0
# 37       ecmf      10u    heightAboveGround   10    20220427      0
# 38       ecmf      10u    heightAboveGround   10    20220427      0
# 39       ecmf      10v    heightAboveGround   10    20220427      0
# 40       ecmf      10v    heightAboveGround   10    20220427      0
# 41       ecmf      10v    heightAboveGround   10    20220427      0
# 42       ecmf      10v    heightAboveGround   10    20220427      0
# 43       ecmf      10v    heightAboveGround   10    20220427      0
# 44       ecmf      10v    heightAboveGround   10    20220427      0
# 45       ecmf      10u    heightAboveGround   10    20220427      0
# 46       ecmf      10v    heightAboveGround   10    20220427      0
# 47       ecmf      10v    heightAboveGround   10    20220427      0
# 48       ecmf      10v    heightAboveGround   10    20220427      0
# 49       ecmf      10v    heightAboveGround   10    20220427      0
# 50       ecmf      10v    heightAboveGround   10    20220427      0
# 51       ecmf      10u    heightAboveGround   10    20220427      0
# 52       ecmf      10u    heightAboveGround   10    20220427      0
# 53       ecmf      10u    heightAboveGround   10    20220427      0
# 54       ecmf      10u    heightAboveGround   10    20220427      0
# 55       ecmf      10v    heightAboveGround   10    20220427      0
# 56       ecmf      10v    heightAboveGround   10    20220427      0
# 57       ecmf      10u    heightAboveGround   10    20220427      0
# 58       ecmf      10v    heightAboveGround   10    20220427      0
# 59       ecmf      10u    heightAboveGround   10    20220427      0
# 60       ecmf      10u    heightAboveGround   10    20220427      0
# 61       ecmf      10v    heightAboveGround   10    20220427      0
# 62       ecmf      10u    heightAboveGround   10    20220427      0
# 63       ecmf      10v    heightAboveGround   10    20220427      0
# 64       ecmf      10u    heightAboveGround   10    20220427      0
# 65       ecmf      10u    heightAboveGround   10    20220427      0
# 66       ecmf      10v    heightAboveGround   10    20220427      0
# 67       ecmf      10u    heightAboveGround   10    20220427      0
# 68       ecmf      10u    heightAboveGround   10    20220427      0
# 69       ecmf      10u    heightAboveGround   10    20220427      0
# 70       ecmf      10u    heightAboveGround   10    20220427      0
# 71       ecmf      10v    heightAboveGround   10    20220427      0
# 72       ecmf      10u    heightAboveGround   10    20220427      0
# 73       ecmf      10u    heightAboveGround   10    20220427      0
# 74       ecmf      10v    heightAboveGround   10    20220427      0
# 75       ecmf      10u    heightAboveGround   10    20220427      0
# 76       ecmf      10u    heightAboveGround   10    20220427      0
# 77       ecmf      10u    heightAboveGround   10    20220427      0
# 78       ecmf      10u    heightAboveGround   10    20220427      0
# 79       ecmf      10u    heightAboveGround   10    20220427      0
# 80       ecmf      10v    heightAboveGround   10    20220427      0
# 81       ecmf      10u    heightAboveGround   10    20220427      0
# 82       ecmf      10u    heightAboveGround   10    20220427      0
# 83       ecmf      10v    heightAboveGround   10    20220427      0
# 84       ecmf      10v    heightAboveGround   10    20220427      0
# 85       ecmf      10u    heightAboveGround   10    20220427      0
# 86       ecmf      10u    heightAboveGround   10    20220427      0
# 87       ecmf      10v    heightAboveGround   10    20220427      0
# 88       ecmf      10v    heightAboveGround   10    20220427      0
# 89       ecmf      10u    heightAboveGround   10    20220427      0
# 90       ecmf      10u    heightAboveGround   10    20220427      0
# 91       ecmf      10v    heightAboveGround   10    20220427      0
# 92       ecmf      10v    heightAboveGround   10    20220427      0
# 93       ecmf      10u    heightAboveGround   10    20220427      0
# 94       ecmf      10v    heightAboveGround   10    20220427      0
# 95       ecmf      10u    heightAboveGround   10    20220427      0
# 96       ecmf      10u    heightAboveGround   10    20220427      0
# 97       ecmf      10u    heightAboveGround   10    20220427      0
# 98       ecmf      10u    heightAboveGround   10    20220427      0
# 99       ecmf      10v    heightAboveGround   10    20220427      0
# 100      ecmf      10v    heightAboveGround   10    20220427      0
# 101      ecmf      10v    heightAboveGround   10    20220427      0
#
#         stepRange dataType number   gridType
# Message
# 0           72       pf      31    regular_ll
# 1           72       pf      25    regular_ll
# 2           72       pf      49    regular_ll
# 3           72       pf      30    regular_ll
# 4           72       pf      50    regular_ll
# 5           72       pf      31    regular_ll
# 6           72       pf      49    regular_ll
# 7           72       pf      33    regular_ll
# 8           72       pf      37    regular_ll
# 9           72       pf      44    regular_ll
# 10          72       pf      28    regular_ll
# 11          72       pf       6    regular_ll
# 12          72       pf      34    regular_ll
# 13          72       pf      27    regular_ll
# 14          72       pf       7    regular_ll
# 15          72       pf      28    regular_ll
# 16          72       pf      48    regular_ll
# 17          72       pf      26    regular_ll
# 18          72       pf      42    regular_ll
# 19          72       pf      23    regular_ll
# 20          72       pf      15    regular_ll
# 21          72       pf      45    regular_ll
# 22          72       cf       0    regular_ll
# 23          72       pf      41    regular_ll
# 24          72       pf      16    regular_ll
# 25          72       pf      32    regular_ll
# 26          72       pf      47    regular_ll
# 27          72       pf      27    regular_ll
# 28          72       pf       9    regular_ll
# 29          72       pf      16    regular_ll
# 30          72       pf      21    regular_ll
# 31          72       pf      42    regular_ll
# 32          72       pf      13    regular_ll
# 33          72       pf      45    regular_ll
# 34          72       pf      47    regular_ll
# 35          72       pf      10    regular_ll
# 36          72       pf      12    regular_ll
# 37          72       pf      11    regular_ll
# 38          72       pf      12    regular_ll
# 39          72       cf       0    regular_ll
# 40          72       pf      11    regular_ll
# 41          72       pf       8    regular_ll
# 42          72       pf      15    regular_ll
# 43          72       pf      36    regular_ll
# 44          72       pf      35    regular_ll
# 45          72       pf      30    regular_ll
# 46          72       pf      38    regular_ll
# 47          72       pf       3    regular_ll
# 48          72       pf      24    regular_ll
# 49          72       pf      26    regular_ll
# 50          72       pf       9    regular_ll
# 51          72       pf      23    regular_ll
# 52          72       pf      29    regular_ll
# 53          72       pf      14    regular_ll
# 54          72       pf      35    regular_ll
# 55          72       pf      40    regular_ll
# 56          72       pf      10    regular_ll
# 57          72       pf      44    regular_ll
# 58          72       pf      25    regular_ll
# 59          72       pf       2    regular_ll
# 60          72       pf      39    regular_ll
# 61          72       pf      20    regular_ll
# 62          72       pf      13    regular_ll
# 63          72       pf       2    regular_ll
# 64          72       pf       3    regular_ll
# 65          72       pf      32    regular_ll
# 66          72       pf      39    regular_ll
# 67          72       pf       8    regular_ll
# 68          72       pf       5    regular_ll
# 69          72       pf      38    regular_ll
# 70          72       pf      20    regular_ll
# 71          72       pf       4    regular_ll
# 72          72       pf      17    regular_ll
# 73          72       pf      48    regular_ll
# 74          72       pf      43    regular_ll
# 75          72       pf       6    regular_ll
# 76          72       pf      24    regular_ll
# 77          72       pf      40    regular_ll
# 78          72       pf      37    regular_ll
# 79          72       pf      46    regular_ll
# 80          72       pf      17    regular_ll
# 81          72       pf      43    regular_ll
# 82          72       pf       1    regular_ll
# 83          72       pf      22    regular_ll
# 84          72       pf      46    regular_ll
# 85          72       pf       7    regular_ll
# 86          72       pf       4    regular_ll
# 87          72       pf      19    regular_ll
# 88          72       pf      41    regular_ll
# 89          72       pf      19    regular_ll
# 90          72       pf      34    regular_ll
# 91          72       pf       5    regular_ll
# 92          72       pf      14    regular_ll
# 93          72       pf      50    regular_ll
# 94          72       pf      18    regular_ll
# 95          72       pf      36    regular_ll
# 96          72       pf      18    regular_ll
# 97          72       pf      22    regular_ll
# 98          72       pf      33    regular_ll
# 99          72       pf      29    regular_ll
# 100         72       pf      21    regular_ll
# 101         72       pf       1    regular_ll

# %% [markdown]
# **ecmwf.data** library has a built in function to calculate the speed from u and v components. It takes u/v fieldsets as input and gives back speed intensity.
# Note that we can give a fieldset on N u/v components, not just one pair.
#
# In this case we will calculate all 51 ensemble members at the same time.
# First we need to filter out u and v and sort the fieldsets.

# %%
u = data.select(shortName= '10u').sort()
v = data.select(shortName= '10v').sort()

# %%
speed = ecdata.speed(u,v)
speed.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>10si</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>10</td><td style='text-align: left;'>20220427</td><td style='text-align: left;'>0</td><td style='text-align: left;'>72</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>207</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# In the end we still need to calculate the mean and spread (as standard deviation) of the wind speed.
# **ecmwf.data** has built in functions to calculate mean and standard deviation of a given fieldset.
# Since our data has only one date,time and step, mean() and stdev() will be calculated over the 51 ensemble members.

# %%
ws_mean = ecdata.mean(speed)
ws_spread = ecdata.stdev(speed)

# %% [markdown]
# ## Plotting the data
# And finally, we can plot the data on the map.

# %%
fig = GeoMap(area_name='europe')

fig.coastlines(land_colour="cream",resolution="medium")

fig.contour_shaded(ws_spread, style="speed_spread_magenta")
fig.contour_lines(ws_mean, style="black_i5_label")

fig.coastlines(resolution="medium")
fig.gridlines()

fig.title(["Ensemble mean and spread for 10m wind speed",
           "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H' />",
           " VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' />, STEP: <grib_info key='step' />"])
fig.legend()

fig.footer("© European Centre for Medium-Range Weather Forecasts (ECMWF) Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use (https://apps.ecmwf.int/datasets/licences/general/)", logo='ecmwf')

fig.show()

# %% [markdown]
# Note that plot produced using open data dataset will slightly differ from one from Open Charts. This is due to different resolution of the data.
# Open data is on 0.4x0.4 resolution, while high resolution data is 0.1x0.1 grid.
