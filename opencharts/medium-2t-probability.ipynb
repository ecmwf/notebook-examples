# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>
#
# # 	Probabilities: 2m temperature

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://apps.ecmwf.int/webapps/opencharts/products/medium-2t-probability

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/UDOC/ECMWF+Open+Data+-+Real+Time).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 1 parameter:
#
# * [2 metre temperature](https://apps.ecmwf.int/codes/grib/param-db/?id=167)

# %% [markdown]
# In this example, we will use:
# - **ecmwf.opendata** Client to download the data
# - **ecmwf.data** library to read and process the data (calculate the speed and probabilities)
# - **ecmwf.geomaps** to plot the result

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#import sys
#!{sys.executable} -m pip install ecmwf-data ecmwf-opendata git+https://github.com/ecmwf/ecmwf-geomaps.git

# %%
import ecmwf.data as ecdata
from ecmwf.geomaps import GeoMap
from ecmwf.opendata import Client

# %%
client = Client("ecmwf", beta=True)

# %%
parameters = ['2t']
filename = 'medium-2t-probability.grib'
filename
# Out:
# 'medium-2t-probability.grib'

# %% [markdown]
# To calculate the probability of 2m Temperature < 0℃ , we need to retrieve all the ensemble members at the given time.
# Setting the **type** to **ef** will download all 50 ensemble members as well as control forecast.

# %%
client.retrieve(
    date=-2,
    time=0,
    step=12,
    stream="enfo",
    type="ef",
    levtype="sfc",
    param=parameters,
    target=filename
)
# Out:
# {'date': '-2', 'time': '0', 'step': '12', 'stream': 'enfo', 'type': 'ef', 'resol': '0p4-beta', '_url': 'https://ai4edataeuwest.blob.core.windows.net/ecmwf', 'extension': 'grib2'}
# {'levtype': ['sfc'], 'param': ['2t'], 'step': ['12'], 'type': ['cf', 'pf']}

# %% [markdown]
# ## Reading and processing the data
# Now we can use **ecmwf.data** to read the file.

# %%
data = ecdata.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>2</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>12</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#         centre shortName    typeOfLevel      level  dataDate  dataTime  \
# Message
# 0        ecmf      2t     heightAboveGround    2    20220116      0
# 1        ecmf      2t     heightAboveGround    2    20220116      0
# 2        ecmf      2t     heightAboveGround    2    20220116      0
# 3        ecmf      2t     heightAboveGround    2    20220116      0
# 4        ecmf      2t     heightAboveGround    2    20220116      0
# 5        ecmf      2t     heightAboveGround    2    20220116      0
# 6        ecmf      2t     heightAboveGround    2    20220116      0
# 7        ecmf      2t     heightAboveGround    2    20220116      0
# 8        ecmf      2t     heightAboveGround    2    20220116      0
# 9        ecmf      2t     heightAboveGround    2    20220116      0
# 10       ecmf      2t     heightAboveGround    2    20220116      0
# 11       ecmf      2t     heightAboveGround    2    20220116      0
# 12       ecmf      2t     heightAboveGround    2    20220116      0
# 13       ecmf      2t     heightAboveGround    2    20220116      0
# 14       ecmf      2t     heightAboveGround    2    20220116      0
# 15       ecmf      2t     heightAboveGround    2    20220116      0
# 16       ecmf      2t     heightAboveGround    2    20220116      0
# 17       ecmf      2t     heightAboveGround    2    20220116      0
# 18       ecmf      2t     heightAboveGround    2    20220116      0
# 19       ecmf      2t     heightAboveGround    2    20220116      0
# 20       ecmf      2t     heightAboveGround    2    20220116      0
# 21       ecmf      2t     heightAboveGround    2    20220116      0
# 22       ecmf      2t     heightAboveGround    2    20220116      0
# 23       ecmf      2t     heightAboveGround    2    20220116      0
# 24       ecmf      2t     heightAboveGround    2    20220116      0
# 25       ecmf      2t     heightAboveGround    2    20220116      0
# 26       ecmf      2t     heightAboveGround    2    20220116      0
# 27       ecmf      2t     heightAboveGround    2    20220116      0
# 28       ecmf      2t     heightAboveGround    2    20220116      0
# 29       ecmf      2t     heightAboveGround    2    20220116      0
# 30       ecmf      2t     heightAboveGround    2    20220116      0
# 31       ecmf      2t     heightAboveGround    2    20220116      0
# 32       ecmf      2t     heightAboveGround    2    20220116      0
# 33       ecmf      2t     heightAboveGround    2    20220116      0
# 34       ecmf      2t     heightAboveGround    2    20220116      0
# 35       ecmf      2t     heightAboveGround    2    20220116      0
# 36       ecmf      2t     heightAboveGround    2    20220116      0
# 37       ecmf      2t     heightAboveGround    2    20220116      0
# 38       ecmf      2t     heightAboveGround    2    20220116      0
# 39       ecmf      2t     heightAboveGround    2    20220116      0
# 40       ecmf      2t     heightAboveGround    2    20220116      0
# 41       ecmf      2t     heightAboveGround    2    20220116      0
# 42       ecmf      2t     heightAboveGround    2    20220116      0
# 43       ecmf      2t     heightAboveGround    2    20220116      0
# 44       ecmf      2t     heightAboveGround    2    20220116      0
# 45       ecmf      2t     heightAboveGround    2    20220116      0
# 46       ecmf      2t     heightAboveGround    2    20220116      0
# 47       ecmf      2t     heightAboveGround    2    20220116      0
# 48       ecmf      2t     heightAboveGround    2    20220116      0
# 49       ecmf      2t     heightAboveGround    2    20220116      0
# 50       ecmf      2t     heightAboveGround    2    20220116      0
#
#         stepRange dataType number   gridType
# Message
# 0           12       pf      22    regular_ll
# 1           12       pf      15    regular_ll
# 2           12       pf      42    regular_ll
# 3           12       pf      44    regular_ll
# 4           12       pf      40    regular_ll
# 5           12       pf      24    regular_ll
# 6           12       pf       3    regular_ll
# 7           12       pf      19    regular_ll
# 8           12       pf      46    regular_ll
# 9           12       pf       8    regular_ll
# 10          12       pf      17    regular_ll
# 11          12       pf       6    regular_ll
# 12          12       pf      20    regular_ll
# 13          12       pf      33    regular_ll
# 14          12       pf      26    regular_ll
# 15          12       pf      28    regular_ll
# 16          12       pf      35    regular_ll
# 17          12       pf      37    regular_ll
# 18          12       pf      48    regular_ll
# 19          12       pf      39    regular_ll
# 20          12       pf       5    regular_ll
# 21          12       pf      31    regular_ll
# 22          12       pf      29    regular_ll
# 23          12       pf      36    regular_ll
# 24          12       pf      30    regular_ll
# 25          12       pf      21    regular_ll
# 26          12       pf      16    regular_ll
# 27          12       pf      25    regular_ll
# 28          12       pf      27    regular_ll
# 29          12       pf      50    regular_ll
# 30          12       pf       7    regular_ll
# 31          12       pf      49    regular_ll
# 32          12       pf       9    regular_ll
# 33          12       pf      32    regular_ll
# 34          12       pf      43    regular_ll
# 35          12       pf      18    regular_ll
# 36          12       pf      38    regular_ll
# 37          12       pf       4    regular_ll
# 38          12       pf      23    regular_ll
# 39          12       pf       2    regular_ll
# 40          12       pf      45    regular_ll
# 41          12       pf      47    regular_ll
# 42          12       pf      41    regular_ll
# 43          12       pf      34    regular_ll
# 44          12       pf      13    regular_ll
# 45          12       pf       1    regular_ll
# 46          12       pf      11    regular_ll
# 47          12       pf      12    regular_ll
# 48          12       pf      14    regular_ll
# 49          12       pf      10    regular_ll
# 50          12       cf       0    regular_ll

# %% [markdown]
# First we convert to Celsius and then make a mask of temperature <0℃. (Of course we could have made a mask data<273.15 as well)

# %%
t_mask = (data - 273.15) < 0

# %% [markdown]
# Now we can calculate the probability:

# %%
prob_t = (ecdata.mean(t_mask) * 100)

# %% [markdown]
# ## Plotting the data
# And finally, we can plot the data on the map.

# %%
fig = GeoMap(area_name='europe', preset='background-foreground')

fig.contour_lines(prob_t, preset="sh_blup_f0t100lst")

fig.title(["Probabilities: 2m temperature < 0 ℃", 
           "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H'/>",
           "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' />, STEP: <grib_info key='step'/>"])
fig.legend()
fig.show()
# Out:
# Magics-warning: description is not a known keyword
