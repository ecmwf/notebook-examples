# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>
#
# # 	Combined probabilities: 2m Temperature < 0C and total precipitation > 1 mm

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://apps.ecmwf.int/webapps/opencharts/products/medium-ens-tp-2t

# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/UDOC/ECMWF+Open+Data+-+Real+Time).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 2 parameters :
#
# * [2 metre temperature](https://apps.ecmwf.int/codes/grib/param-db/?id=167)
# * [Total precipitation](https://apps.ecmwf.int/codes/grib/param-db/?id=228)

# %% [markdown]
# In this example, we will use:
# - **ecmwf.opendata** Client to download the data
# - **ecmwf.data** library to read and process the data
# - **ecmwf.geomaps** to plot the result

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#import sys
#!{sys.executable} -m pip install ecmwf-data ecmwf-opendata git+https://github.com/ecmwf/ecmwf-geomaps.git

# %%
import ecmwf.data as ecdata
from ecmwf.geomaps import GeoMap
from ecmwf.opendata import Client

# %%
client = Client("ecmwf", beta=True)

# %%
parameters = ['2t','tp']
filename = 'medium-ens-tp-2t.grib'
filename
# Out:
# 'medium-ens-tp-2t.grib'

# %%
client.retrieve(
    date=-2,
    time=0,
    step=[21,24],
    stream="enfo",
    type="ef",
    levtype="sfc",
    param=parameters,
    target=filename
)
# Out:
# {'date': '-2', 'time': '0', 'step': '21', 'stream': 'enfo', 'type': 'ef', 'resol': '0p4-beta', '_url': 'https://ai4edataeuwest.blob.core.windows.net/ecmwf', 'extension': 'grib2'}
# {'date': '-2', 'time': '0', 'step': '24', 'stream': 'enfo', 'type': 'ef', 'resol': '0p4-beta', '_url': 'https://ai4edataeuwest.blob.core.windows.net/ecmwf', 'extension': 'grib2'}
# {'levtype': ['sfc'], 'param': ['2t', 'tp'], 'step': ['21', '24'], 'type': ['cf', 'pf']}

# %% [markdown]
# ## Reading and processing the data
# Now we can use **ecmwf.data** to read the file.

# %%
data = ecdata.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>2</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>21,24</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>tp</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>21,24</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>228228</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#         centre shortName    typeOfLevel      level  dataDate  dataTime  \
# Message
# 0        ecmf      tp               surface    0    20220116      0
# 1        ecmf      tp               surface    0    20220116      0
# 2        ecmf      tp               surface    0    20220116      0
# 3        ecmf      tp               surface    0    20220116      0
# 4        ecmf      tp               surface    0    20220116      0
# 5        ecmf      tp               surface    0    20220116      0
# 6        ecmf      tp               surface    0    20220116      0
# 7        ecmf      tp               surface    0    20220116      0
# 8        ecmf      tp               surface    0    20220116      0
# 9        ecmf      tp               surface    0    20220116      0
# 10       ecmf      tp               surface    0    20220116      0
# 11       ecmf      tp               surface    0    20220116      0
# 12       ecmf      tp               surface    0    20220116      0
# 13       ecmf      tp               surface    0    20220116      0
# 14       ecmf      tp               surface    0    20220116      0
# 15       ecmf      tp               surface    0    20220116      0
# 16       ecmf      tp               surface    0    20220116      0
# 17       ecmf      tp               surface    0    20220116      0
# 18       ecmf      tp               surface    0    20220116      0
# 19       ecmf      tp               surface    0    20220116      0
# 20       ecmf      tp               surface    0    20220116      0
# 21       ecmf      tp               surface    0    20220116      0
# 22       ecmf      tp               surface    0    20220116      0
# 23       ecmf      tp               surface    0    20220116      0
# 24       ecmf      2t     heightAboveGround    2    20220116      0
# 25       ecmf      2t     heightAboveGround    2    20220116      0
# 26       ecmf      2t     heightAboveGround    2    20220116      0
# 27       ecmf      2t     heightAboveGround    2    20220116      0
# 28       ecmf      2t     heightAboveGround    2    20220116      0
# 29       ecmf      2t     heightAboveGround    2    20220116      0
# 30       ecmf      2t     heightAboveGround    2    20220116      0
# 31       ecmf      2t     heightAboveGround    2    20220116      0
# 32       ecmf      2t     heightAboveGround    2    20220116      0
# 33       ecmf      2t     heightAboveGround    2    20220116      0
# 34       ecmf      2t     heightAboveGround    2    20220116      0
# 35       ecmf      2t     heightAboveGround    2    20220116      0
# 36       ecmf      2t     heightAboveGround    2    20220116      0
# 37       ecmf      2t     heightAboveGround    2    20220116      0
# 38       ecmf      2t     heightAboveGround    2    20220116      0
# 39       ecmf      2t     heightAboveGround    2    20220116      0
# 40       ecmf      2t     heightAboveGround    2    20220116      0
# 41       ecmf      2t     heightAboveGround    2    20220116      0
# 42       ecmf      2t     heightAboveGround    2    20220116      0
# 43       ecmf      2t     heightAboveGround    2    20220116      0
# 44       ecmf      2t     heightAboveGround    2    20220116      0
# 45       ecmf      tp               surface    0    20220116      0
# 46       ecmf      tp               surface    0    20220116      0
# 47       ecmf      tp               surface    0    20220116      0
# 48       ecmf      2t     heightAboveGround    2    20220116      0
# 49       ecmf      tp               surface    0    20220116      0
# 50       ecmf      tp               surface    0    20220116      0
# 51       ecmf      tp               surface    0    20220116      0
# 52       ecmf      tp               surface    0    20220116      0
# 53       ecmf      tp               surface    0    20220116      0
# 54       ecmf      tp               surface    0    20220116      0
# 55       ecmf      tp               surface    0    20220116      0
# 56       ecmf      tp               surface    0    20220116      0
# 57       ecmf      tp               surface    0    20220116      0
# 58       ecmf      tp               surface    0    20220116      0
# 59       ecmf      tp               surface    0    20220116      0
# 60       ecmf      tp               surface    0    20220116      0
# 61       ecmf      tp               surface    0    20220116      0
# 62       ecmf      2t     heightAboveGround    2    20220116      0
# 63       ecmf      tp               surface    0    20220116      0
# 64       ecmf      2t     heightAboveGround    2    20220116      0
# 65       ecmf      2t     heightAboveGround    2    20220116      0
# 66       ecmf      tp               surface    0    20220116      0
# 67       ecmf      2t     heightAboveGround    2    20220116      0
# 68       ecmf      2t     heightAboveGround    2    20220116      0
# 69       ecmf      2t     heightAboveGround    2    20220116      0
# 70       ecmf      2t     heightAboveGround    2    20220116      0
# 71       ecmf      tp               surface    0    20220116      0
# 72       ecmf      2t     heightAboveGround    2    20220116      0
# 73       ecmf      2t     heightAboveGround    2    20220116      0
# 74       ecmf      2t     heightAboveGround    2    20220116      0
# 75       ecmf      2t     heightAboveGround    2    20220116      0
# 76       ecmf      tp               surface    0    20220116      0
# 77       ecmf      2t     heightAboveGround    2    20220116      0
# 78       ecmf      2t     heightAboveGround    2    20220116      0
# 79       ecmf      2t     heightAboveGround    2    20220116      0
# 80       ecmf      2t     heightAboveGround    2    20220116      0
# 81       ecmf      tp               surface    0    20220116      0
# 82       ecmf      2t     heightAboveGround    2    20220116      0
# 83       ecmf      2t     heightAboveGround    2    20220116      0
# 84       ecmf      2t     heightAboveGround    2    20220116      0
# 85       ecmf      2t     heightAboveGround    2    20220116      0
# 86       ecmf      2t     heightAboveGround    2    20220116      0
# 87       ecmf      tp               surface    0    20220116      0
# 88       ecmf      2t     heightAboveGround    2    20220116      0
# 89       ecmf      2t     heightAboveGround    2    20220116      0
# 90       ecmf      tp               surface    0    20220116      0
# 91       ecmf      2t     heightAboveGround    2    20220116      0
# 92       ecmf      2t     heightAboveGround    2    20220116      0
# 93       ecmf      2t     heightAboveGround    2    20220116      0
# 94       ecmf      2t     heightAboveGround    2    20220116      0
# 95       ecmf      tp               surface    0    20220116      0
# 96       ecmf      2t     heightAboveGround    2    20220116      0
# 97       ecmf      2t     heightAboveGround    2    20220116      0
# 98       ecmf      tp               surface    0    20220116      0
# 99       ecmf      tp               surface    0    20220116      0
# 100      ecmf      2t     heightAboveGround    2    20220116      0
# 101      ecmf      tp               surface    0    20220116      0
# 102      ecmf      tp               surface    0    20220116      0
# 103      ecmf      tp               surface    0    20220116      0
# 104      ecmf      tp               surface    0    20220116      0
# 105      ecmf      tp               surface    0    20220116      0
# 106      ecmf      tp               surface    0    20220116      0
# 107      ecmf      tp               surface    0    20220116      0
# 108      ecmf      tp               surface    0    20220116      0
# 109      ecmf      tp               surface    0    20220116      0
# 110      ecmf      tp               surface    0    20220116      0
# 111      ecmf      tp               surface    0    20220116      0
# 112      ecmf      tp               surface    0    20220116      0
# 113      ecmf      tp               surface    0    20220116      0
# 114      ecmf      tp               surface    0    20220116      0
# 115      ecmf      tp               surface    0    20220116      0
# 116      ecmf      tp               surface    0    20220116      0
# 117      ecmf      tp               surface    0    20220116      0
# 118      ecmf      tp               surface    0    20220116      0
# 119      ecmf      tp               surface    0    20220116      0
# 120      ecmf      tp               surface    0    20220116      0
# 121      ecmf      tp               surface    0    20220116      0
# 122      ecmf      tp               surface    0    20220116      0
# 123      ecmf      tp               surface    0    20220116      0
# 124      ecmf      tp               surface    0    20220116      0
# 125      ecmf      tp               surface    0    20220116      0
# 126      ecmf      2t     heightAboveGround    2    20220116      0
# 127      ecmf      2t     heightAboveGround    2    20220116      0
# 128      ecmf      2t     heightAboveGround    2    20220116      0
# 129      ecmf      2t     heightAboveGround    2    20220116      0
# 130      ecmf      2t     heightAboveGround    2    20220116      0
# 131      ecmf      2t     heightAboveGround    2    20220116      0
# 132      ecmf      2t     heightAboveGround    2    20220116      0
# 133      ecmf      2t     heightAboveGround    2    20220116      0
# 134      ecmf      2t     heightAboveGround    2    20220116      0
# 135      ecmf      2t     heightAboveGround    2    20220116      0
# 136      ecmf      2t     heightAboveGround    2    20220116      0
# 137      ecmf      2t     heightAboveGround    2    20220116      0
# 138      ecmf      2t     heightAboveGround    2    20220116      0
# 139      ecmf      2t     heightAboveGround    2    20220116      0
# 140      ecmf      2t     heightAboveGround    2    20220116      0
# 141      ecmf      2t     heightAboveGround    2    20220116      0
# 142      ecmf      2t     heightAboveGround    2    20220116      0
# 143      ecmf      2t     heightAboveGround    2    20220116      0
# 144      ecmf      2t     heightAboveGround    2    20220116      0
# 145      ecmf      2t     heightAboveGround    2    20220116      0
# 146      ecmf      2t     heightAboveGround    2    20220116      0
# 147      ecmf      2t     heightAboveGround    2    20220116      0
# 148      ecmf      tp               surface    0    20220116      0
# 149      ecmf      tp               surface    0    20220116      0
# 150      ecmf      tp               surface    0    20220116      0
# 151      ecmf      tp               surface    0    20220116      0
# 152      ecmf      tp               surface    0    20220116      0
# 153      ecmf      tp               surface    0    20220116      0
# 154      ecmf      tp               surface    0    20220116      0
# 155      ecmf      tp               surface    0    20220116      0
# 156      ecmf      tp               surface    0    20220116      0
# 157      ecmf      tp               surface    0    20220116      0
# 158      ecmf      tp               surface    0    20220116      0
# 159      ecmf      2t     heightAboveGround    2    20220116      0
# 160      ecmf      tp               surface    0    20220116      0
# 161      ecmf      tp               surface    0    20220116      0
# 162      ecmf      tp               surface    0    20220116      0
# 163      ecmf      2t     heightAboveGround    2    20220116      0
# 164      ecmf      tp               surface    0    20220116      0
# 165      ecmf      tp               surface    0    20220116      0
# 166      ecmf      tp               surface    0    20220116      0
# 167      ecmf      2t     heightAboveGround    2    20220116      0
# 168      ecmf      2t     heightAboveGround    2    20220116      0
# 169      ecmf      2t     heightAboveGround    2    20220116      0
# 170      ecmf      tp               surface    0    20220116      0
# 171      ecmf      tp               surface    0    20220116      0
# 172      ecmf      2t     heightAboveGround    2    20220116      0
# 173      ecmf      2t     heightAboveGround    2    20220116      0
# 174      ecmf      tp               surface    0    20220116      0
# 175      ecmf      2t     heightAboveGround    2    20220116      0
# 176      ecmf      tp               surface    0    20220116      0
# 177      ecmf      2t     heightAboveGround    2    20220116      0
# 178      ecmf      2t     heightAboveGround    2    20220116      0
# 179      ecmf      2t     heightAboveGround    2    20220116      0
# 180      ecmf      2t     heightAboveGround    2    20220116      0
# 181      ecmf      2t     heightAboveGround    2    20220116      0
# 182      ecmf      2t     heightAboveGround    2    20220116      0
# 183      ecmf      tp               surface    0    20220116      0
# 184      ecmf      2t     heightAboveGround    2    20220116      0
# 185      ecmf      2t     heightAboveGround    2    20220116      0
# 186      ecmf      2t     heightAboveGround    2    20220116      0
# 187      ecmf      2t     heightAboveGround    2    20220116      0
# 188      ecmf      2t     heightAboveGround    2    20220116      0
# 189      ecmf      2t     heightAboveGround    2    20220116      0
# 190      ecmf      2t     heightAboveGround    2    20220116      0
# 191      ecmf      2t     heightAboveGround    2    20220116      0
# 192      ecmf      tp               surface    0    20220116      0
# 193      ecmf      2t     heightAboveGround    2    20220116      0
# 194      ecmf      2t     heightAboveGround    2    20220116      0
# 195      ecmf      2t     heightAboveGround    2    20220116      0
# 196      ecmf      2t     heightAboveGround    2    20220116      0
# 197      ecmf      2t     heightAboveGround    2    20220116      0
# 198      ecmf      tp               surface    0    20220116      0
# 199      ecmf      2t     heightAboveGround    2    20220116      0
# 200      ecmf      tp               surface    0    20220116      0
# 201      ecmf      tp               surface    0    20220116      0
# 202      ecmf      2t     heightAboveGround    2    20220116      0
# 203      ecmf      tp               surface    0    20220116      0
#
#         stepRange dataType number   gridType
# Message
# 0           21       pf      30    regular_ll
# 1           21       pf      16    regular_ll
# 2           21       pf       9    regular_ll
# 3           21       pf      23    regular_ll
# 4           21       pf      18    regular_ll
# 5           21       pf      43    regular_ll
# 6           21       pf       4    regular_ll
# 7           21       pf      14    regular_ll
# 8           21       pf      41    regular_ll
# 9           21       pf      38    regular_ll
# 10          21       pf      45    regular_ll
# 11          21       pf       7    regular_ll
# 12          21       pf      21    regular_ll
# 13          21       pf      25    regular_ll
# 14          21       pf      12    regular_ll
# 15          21       pf      49    regular_ll
# 16          21       pf      27    regular_ll
# 17          21       pf      32    regular_ll
# 18          21       pf       2    regular_ll
# 19          21       pf      50    regular_ll
# 20          21       pf      47    regular_ll
# 21          21       pf      36    regular_ll
# 22          21       pf      29    regular_ll
# 23          21       pf      34    regular_ll
# 24          21       pf      33    regular_ll
# 25          21       pf      39    regular_ll
# 26          21       pf      48    regular_ll
# 27          21       pf       6    regular_ll
# 28          21       pf      37    regular_ll
# 29          21       pf      40    regular_ll
# 30          21       pf      26    regular_ll
# 31          21       pf      15    regular_ll
# 32          21       pf      22    regular_ll
# 33          21       pf      31    regular_ll
# 34          21       pf      46    regular_ll
# 35          21       pf       5    regular_ll
# 36          21       pf      20    regular_ll
# 37          21       pf      17    regular_ll
# 38          21       pf      19    regular_ll
# 39          21       pf      35    regular_ll
# 40          21       pf       3    regular_ll
# 41          21       pf       8    regular_ll
# 42          21       pf      44    regular_ll
# 43          21       pf      24    regular_ll
# 44          21       pf      42    regular_ll
# 45          21       pf       6    regular_ll
# 46          21       pf      33    regular_ll
# 47          21       pf      48    regular_ll
# 48          21       pf      28    regular_ll
# 49          21       pf      39    regular_ll
# 50          21       pf      26    regular_ll
# 51          21       pf      40    regular_ll
# 52          21       pf      22    regular_ll
# 53          21       pf      37    regular_ll
# 54          21       pf      17    regular_ll
# 55          21       pf      20    regular_ll
# 56          21       pf      15    regular_ll
# 57          21       pf      19    regular_ll
# 58          21       pf      31    regular_ll
# 59          21       pf      35    regular_ll
# 60          21       pf      46    regular_ll
# 61          21       pf       5    regular_ll
# 62          21       pf      25    regular_ll
# 63          21       pf       3    regular_ll
# 64          21       pf      16    regular_ll
# 65          21       pf      47    regular_ll
# 66          21       pf      42    regular_ll
# 67          21       pf      43    regular_ll
# 68          21       pf      32    regular_ll
# 69          21       pf      36    regular_ll
# 70          21       pf       7    regular_ll
# 71          21       pf       8    regular_ll
# 72          21       pf      50    regular_ll
# 73          21       pf      34    regular_ll
# 74          21       pf      21    regular_ll
# 75          21       pf       9    regular_ll
# 76          21       pf      24    regular_ll
# 77          21       pf      38    regular_ll
# 78          21       pf      30    regular_ll
# 79          21       pf       2    regular_ll
# 80          21       pf       4    regular_ll
# 81          21       pf      44    regular_ll
# 82          21       pf      49    regular_ll
# 83          21       pf      45    regular_ll
# 84          21       pf      27    regular_ll
# 85          21       pf      23    regular_ll
# 86          21       pf      41    regular_ll
# 87          21       pf      28    regular_ll
# 88          21       pf      29    regular_ll
# 89          21       pf      18    regular_ll
# 90          21       pf      10    regular_ll
# 91          21       pf      13    regular_ll
# 92          21       pf       1    regular_ll
# 93          21       pf      11    regular_ll
# 94          21       pf      12    regular_ll
# 95          21       pf      13    regular_ll
# 96          21       pf      14    regular_ll
# 97          21       pf      10    regular_ll
# 98          21       pf       1    regular_ll
# 99          21       pf      11    regular_ll
# 100         21       cf       0    regular_ll
# 101         21       cf       0    regular_ll
# 102         24       pf      49    regular_ll
# 103         24       pf      25    regular_ll
# 104         24       pf      18    regular_ll
# 105         24       pf      12    regular_ll
# 106         24       pf      14    regular_ll
# 107         24       pf       4    regular_ll
# 108         24       pf      45    regular_ll
# 109         24       pf      50    regular_ll
# 110         24       pf      30    regular_ll
# 111         24       pf       2    regular_ll
# 112         24       pf      43    regular_ll
# 113         24       pf      27    regular_ll
# 114         24       pf      47    regular_ll
# 115         24       pf      16    regular_ll
# 116         24       pf      38    regular_ll
# 117         24       pf      32    regular_ll
# 118         24       pf      21    regular_ll
# 119         24       pf      23    regular_ll
# 120         24       pf       9    regular_ll
# 121         24       pf      41    regular_ll
# 122         24       pf      34    regular_ll
# 123         24       pf       7    regular_ll
# 124         24       pf      29    regular_ll
# 125         24       pf      36    regular_ll
# 126         24       pf      20    regular_ll
# 127         24       pf      24    regular_ll
# 128         24       pf      15    regular_ll
# 129         24       pf      40    regular_ll
# 130         24       pf      28    regular_ll
# 131         24       pf      44    regular_ll
# 132         24       pf      19    regular_ll
# 133         24       pf      48    regular_ll
# 134         24       pf      17    regular_ll
# 135         24       pf      35    regular_ll
# 136         24       pf      46    regular_ll
# 137         24       pf      26    regular_ll
# 138         24       pf      37    regular_ll
# 139         24       pf      39    regular_ll
# 140         24       pf       6    regular_ll
# 141         24       pf      22    regular_ll
# 142         24       pf      31    regular_ll
# 143         24       pf       8    regular_ll
# 144         24       pf      42    regular_ll
# 145         24       pf      33    regular_ll
# 146         24       pf       3    regular_ll
# 147         24       pf       5    regular_ll
# 148         24       pf      20    regular_ll
# 149         24       pf      24    regular_ll
# 150         24       pf      40    regular_ll
# 151         24       pf      17    regular_ll
# 152         24       pf       6    regular_ll
# 153         24       pf      35    regular_ll
# 154         24       pf      19    regular_ll
# 155         24       pf      28    regular_ll
# 156         24       pf      22    regular_ll
# 157         24       pf      48    regular_ll
# 158         24       pf      37    regular_ll
# 159         24       pf      45    regular_ll
# 160         24       pf      46    regular_ll
# 161         24       pf      26    regular_ll
# 162         24       pf      44    regular_ll
# 163         24       pf      34    regular_ll
# 164         24       pf      39    regular_ll
# 165         24       pf      42    regular_ll
# 166         24       pf      15    regular_ll
# 167         24       pf      16    regular_ll
# 168         24       pf      25    regular_ll
# 169         24       pf       4    regular_ll
# 170         24       pf      31    regular_ll
# 171         24       pf       8    regular_ll
# 172         24       pf      32    regular_ll
# 173         24       pf      38    regular_ll
# 174         24       pf       3    regular_ll
# 175         24       pf      30    regular_ll
# 176         24       pf       5    regular_ll
# 177         24       pf      50    regular_ll
# 178         24       pf      43    regular_ll
# 179         24       pf      29    regular_ll
# 180         24       pf      41    regular_ll
# 181         24       pf       9    regular_ll
# 182         24       pf      23    regular_ll
# 183         24       pf      33    regular_ll
# 184         24       pf      21    regular_ll
# 185         24       pf       2    regular_ll
# 186         24       pf      18    regular_ll
# 187         24       pf      36    regular_ll
# 188         24       pf      47    regular_ll
# 189         24       pf       7    regular_ll
# 190         24       pf      49    regular_ll
# 191         24       pf      27    regular_ll
# 192         24       pf      10    regular_ll
# 193         24       pf      13    regular_ll
# 194         24       pf      11    regular_ll
# 195         24       pf       1    regular_ll
# 196         24       pf      12    regular_ll
# 197         24       pf      14    regular_ll
# 198         24       pf      11    regular_ll
# 199         24       pf      10    regular_ll
# 200         24       pf      13    regular_ll
# 201         24       pf       1    regular_ll
# 202         24       cf       0    regular_ll
# 203         24       cf       0    regular_ll

# %%
t2m = data.select(shortName='2t',step=24)
t2m.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>2</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>24</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %%
mask = ecdata.Fieldset()
for number in range(51):
    t2m_n = t2m.select(number = number,)
    tp_24 = data.select(shortName='tp',step=24, number = number)
    tp_21 = data.select(shortName='tp',step=21, number = number)
    tp_n = tp_24 - tp_21
    m = (t2m_n <= 273.15) & (tp_n >= 1)
    mask.append(m)

prob = (ecdata.mean(mask))*100

# %%
## Plotting the data
prob.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>2</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>24</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %%
fig = GeoMap(area_name='europe', preset='background-foreground')

fig.contour_lines(prob, preset="sh_blup_f0t100lst")

fig.title(["Combined probabilities: 2m Temperature < 0C and total precipitation > 1 mm",
           " START TIME: <grib_info key='base-date' format='%a %d %B %Y %H'/> ",
           " VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' />, STEP: <grib_info key='step'/>"])
fig.legend()

fig.show()
# Out:
# Magics-warning: description is not a known keyword
