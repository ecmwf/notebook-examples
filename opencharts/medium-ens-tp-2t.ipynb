# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <img src="data:image/png;base64,..." width="500px"/>
# </div>
#
# # 	Combined probabilities: 2m Temperature < 0&deg;C and total precipitation > 1 mm

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://charts.ecmwf.int/products/medium-ens-tp-2t

# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/DAC/ECMWF+open+data%3A+real-time+forecasts+from+IFS+and+AIFS).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input 2 parameters :
#
# * [2 metre temperature](https://codes.ecmwf.int/grib/param-db/167)
# * [Total precipitation](https://codes.ecmwf.int/grib/param-db/228)

# %% [markdown]
# In this example, we will use:
# - [**ecmwf.opendata**](https://github.com/ecmwf/ecmwf-opendata) Client to download the data
# - [**Metview**](https://metview.readthedocs.io/en/latest/) library to read, process and plot the data

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#!pip install ecmwf-opendata metview metview-python

# %%
import metview as mv
from ecmwf.opendata import Client

# %%
client = Client("ecmwf", beta=True)

# %%
parameters = ['2t','tp']
filename = 'medium-ens-tp-2t.grib'
filename
# Out:
# 'medium-ens-tp-2t.grib'

# %% [markdown]
# We need to put both **cf** and **pf** as type **type** to download all 50 ensemble members as well as the control forecast.
# Setting date to 0 will download today's data.
# Removing date and time altogether from the request will download the latest data.
# Try commenting out date and time to download latest forecast!

# %%
client.retrieve(
    date=0,
    time=0,
    step=[21,24],
    stream="enfo",
    type=['cf', 'pf'],
    levtype="sfc",
    param=parameters,
    target=filename
)
# Out:
# <multiple>:   0%|          | 0.00/142M [00:00<?, ?B/s]

# %% [markdown]
# ## Reading and processing the data
# Now we can use **ecmwf.data** to read the file.

# %%
data = mv.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>2</td><td style='text-align: left;'>20250108</td><td style='text-align: left;'>0</td><td style='text-align: left;'>21,24</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr><tr><th style='text-align: right;'>tp</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20250108</td><td style='text-align: left;'>0</td><td style='text-align: left;'>21,24</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>228</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#         centre shortName    typeOfLevel      level  dataDate  dataTime  \
# Message
# 0        ecmf      tp               surface    0    20250108      0
# 1        ecmf      2t     heightAboveGround    2    20250108      0
# 2        ecmf      tp               surface    0    20250108      0
# 3        ecmf      2t     heightAboveGround    2    20250108      0
# 4        ecmf      2t     heightAboveGround    2    20250108      0
# 5        ecmf      tp               surface    0    20250108      0
# 6        ecmf      tp               surface    0    20250108      0
# 7        ecmf      tp               surface    0    20250108      0
# 8        ecmf      2t     heightAboveGround    2    20250108      0
# 9        ecmf      2t     heightAboveGround    2    20250108      0
# 10       ecmf      tp               surface    0    20250108      0
# 11       ecmf      tp               surface    0    20250108      0
# 12       ecmf      tp               surface    0    20250108      0
# 13       ecmf      tp               surface    0    20250108      0
# 14       ecmf      tp               surface    0    20250108      0
# 15       ecmf      2t     heightAboveGround    2    20250108      0
# 16       ecmf      2t     heightAboveGround    2    20250108      0
# 17       ecmf      2t     heightAboveGround    2    20250108      0
# 18       ecmf      2t     heightAboveGround    2    20250108      0
# 19       ecmf      2t     heightAboveGround    2    20250108      0
# 20       ecmf      tp               surface    0    20250108      0
# 21       ecmf      tp               surface    0    20250108      0
# 22       ecmf      tp               surface    0    20250108      0
# 23       ecmf      tp               surface    0    20250108      0
# 24       ecmf      tp               surface    0    20250108      0
# 25       ecmf      2t     heightAboveGround    2    20250108      0
# 26       ecmf      tp               surface    0    20250108      0
# 27       ecmf      tp               surface    0    20250108      0
# 28       ecmf      tp               surface    0    20250108      0
# 29       ecmf      2t     heightAboveGround    2    20250108      0
# 30       ecmf      2t     heightAboveGround    2    20250108      0
# 31       ecmf      2t     heightAboveGround    2    20250108      0
# 32       ecmf      2t     heightAboveGround    2    20250108      0
# 33       ecmf      tp               surface    0    20250108      0
# 34       ecmf      tp               surface    0    20250108      0
# 35       ecmf      tp               surface    0    20250108      0
# 36       ecmf      tp               surface    0    20250108      0
# 37       ecmf      tp               surface    0    20250108      0
# 38       ecmf      2t     heightAboveGround    2    20250108      0
# 39       ecmf      tp               surface    0    20250108      0
# 40       ecmf      tp               surface    0    20250108      0
# 41       ecmf      2t     heightAboveGround    2    20250108      0
# 42       ecmf      2t     heightAboveGround    2    20250108      0
# 43       ecmf      2t     heightAboveGround    2    20250108      0
# 44       ecmf      2t     heightAboveGround    2    20250108      0
# 45       ecmf      2t     heightAboveGround    2    20250108      0
# 46       ecmf      2t     heightAboveGround    2    20250108      0
# 47       ecmf      2t     heightAboveGround    2    20250108      0
# 48       ecmf      2t     heightAboveGround    2    20250108      0
# 49       ecmf      tp               surface    0    20250108      0
# 50       ecmf      2t     heightAboveGround    2    20250108      0
# 51       ecmf      tp               surface    0    20250108      0
# 52       ecmf      tp               surface    0    20250108      0
# 53       ecmf      tp               surface    0    20250108      0
# 54       ecmf      tp               surface    0    20250108      0
# 55       ecmf      tp               surface    0    20250108      0
# 56       ecmf      2t     heightAboveGround    2    20250108      0
# 57       ecmf      2t     heightAboveGround    2    20250108      0
# 58       ecmf      2t     heightAboveGround    2    20250108      0
# 59       ecmf      2t     heightAboveGround    2    20250108      0
# 60       ecmf      2t     heightAboveGround    2    20250108      0
# 61       ecmf      2t     heightAboveGround    2    20250108      0
# 62       ecmf      tp               surface    0    20250108      0
# 63       ecmf      tp               surface    0    20250108      0
# 64       ecmf      2t     heightAboveGround    2    20250108      0
# 65       ecmf      2t     heightAboveGround    2    20250108      0
# 66       ecmf      2t     heightAboveGround    2    20250108      0
# 67       ecmf      2t     heightAboveGround    2    20250108      0
# 68       ecmf      tp               surface    0    20250108      0
# 69       ecmf      2t     heightAboveGround    2    20250108      0
# 70       ecmf      tp               surface    0    20250108      0
# 71       ecmf      tp               surface    0    20250108      0
# 72       ecmf      tp               surface    0    20250108      0
# 73       ecmf      tp               surface    0    20250108      0
# 74       ecmf      tp               surface    0    20250108      0
# 75       ecmf      tp               surface    0    20250108      0
# 76       ecmf      2t     heightAboveGround    2    20250108      0
# 77       ecmf      2t     heightAboveGround    2    20250108      0
# 78       ecmf      2t     heightAboveGround    2    20250108      0
# 79       ecmf      tp               surface    0    20250108      0
# 80       ecmf      2t     heightAboveGround    2    20250108      0
# 81       ecmf      2t     heightAboveGround    2    20250108      0
# 82       ecmf      tp               surface    0    20250108      0
# 83       ecmf      tp               surface    0    20250108      0
# 84       ecmf      2t     heightAboveGround    2    20250108      0
# 85       ecmf      2t     heightAboveGround    2    20250108      0
# 86       ecmf      tp               surface    0    20250108      0
# 87       ecmf      2t     heightAboveGround    2    20250108      0
# 88       ecmf      2t     heightAboveGround    2    20250108      0
# 89       ecmf      tp               surface    0    20250108      0
# 90       ecmf      2t     heightAboveGround    2    20250108      0
# 91       ecmf      2t     heightAboveGround    2    20250108      0
# 92       ecmf      tp               surface    0    20250108      0
# 93       ecmf      2t     heightAboveGround    2    20250108      0
# 94       ecmf      2t     heightAboveGround    2    20250108      0
# 95       ecmf      2t     heightAboveGround    2    20250108      0
# 96       ecmf      2t     heightAboveGround    2    20250108      0
# 97       ecmf      tp               surface    0    20250108      0
# 98       ecmf      tp               surface    0    20250108      0
# 99       ecmf      tp               surface    0    20250108      0
# 100      ecmf      tp               surface    0    20250108      0
# 101      ecmf      tp               surface    0    20250108      0
# 102      ecmf      tp               surface    0    20250108      0
# 103      ecmf      2t     heightAboveGround    2    20250108      0
# 104      ecmf      tp               surface    0    20250108      0
# 105      ecmf      tp               surface    0    20250108      0
# 106      ecmf      2t     heightAboveGround    2    20250108      0
# 107      ecmf      tp               surface    0    20250108      0
# 108      ecmf      tp               surface    0    20250108      0
# 109      ecmf      2t     heightAboveGround    2    20250108      0
# 110      ecmf      2t     heightAboveGround    2    20250108      0
# 111      ecmf      2t     heightAboveGround    2    20250108      0
# 112      ecmf      tp               surface    0    20250108      0
# 113      ecmf      tp               surface    0    20250108      0
# 114      ecmf      tp               surface    0    20250108      0
# 115      ecmf      tp               surface    0    20250108      0
# 116      ecmf      tp               surface    0    20250108      0
# 117      ecmf      tp               surface    0    20250108      0
# 118      ecmf      2t     heightAboveGround    2    20250108      0
# 119      ecmf      2t     heightAboveGround    2    20250108      0
# 120      ecmf      tp               surface    0    20250108      0
# 121      ecmf      2t     heightAboveGround    2    20250108      0
# 122      ecmf      tp               surface    0    20250108      0
# 123      ecmf      tp               surface    0    20250108      0
# 124      ecmf      2t     heightAboveGround    2    20250108      0
# 125      ecmf      tp               surface    0    20250108      0
# 126      ecmf      2t     heightAboveGround    2    20250108      0
# 127      ecmf      2t     heightAboveGround    2    20250108      0
# 128      ecmf      2t     heightAboveGround    2    20250108      0
# 129      ecmf      tp               surface    0    20250108      0
# 130      ecmf      2t     heightAboveGround    2    20250108      0
# 131      ecmf      tp               surface    0    20250108      0
# 132      ecmf      tp               surface    0    20250108      0
# 133      ecmf      2t     heightAboveGround    2    20250108      0
# 134      ecmf      tp               surface    0    20250108      0
# 135      ecmf      tp               surface    0    20250108      0
# 136      ecmf      2t     heightAboveGround    2    20250108      0
# 137      ecmf      tp               surface    0    20250108      0
# 138      ecmf      tp               surface    0    20250108      0
# 139      ecmf      tp               surface    0    20250108      0
# 140      ecmf      2t     heightAboveGround    2    20250108      0
# 141      ecmf      2t     heightAboveGround    2    20250108      0
# 142      ecmf      2t     heightAboveGround    2    20250108      0
# 143      ecmf      tp               surface    0    20250108      0
# 144      ecmf      2t     heightAboveGround    2    20250108      0
# 145      ecmf      tp               surface    0    20250108      0
# 146      ecmf      2t     heightAboveGround    2    20250108      0
# 147      ecmf      2t     heightAboveGround    2    20250108      0
# 148      ecmf      2t     heightAboveGround    2    20250108      0
# 149      ecmf      2t     heightAboveGround    2    20250108      0
# 150      ecmf      2t     heightAboveGround    2    20250108      0
# 151      ecmf      tp               surface    0    20250108      0
# 152      ecmf      2t     heightAboveGround    2    20250108      0
# 153      ecmf      tp               surface    0    20250108      0
# 154      ecmf      tp               surface    0    20250108      0
# 155      ecmf      tp               surface    0    20250108      0
# 156      ecmf      2t     heightAboveGround    2    20250108      0
# 157      ecmf      tp               surface    0    20250108      0
# 158      ecmf      tp               surface    0    20250108      0
# 159      ecmf      2t     heightAboveGround    2    20250108      0
# 160      ecmf      2t     heightAboveGround    2    20250108      0
# 161      ecmf      2t     heightAboveGround    2    20250108      0
# 162      ecmf      2t     heightAboveGround    2    20250108      0
# 163      ecmf      tp               surface    0    20250108      0
# 164      ecmf      2t     heightAboveGround    2    20250108      0
# 165      ecmf      tp               surface    0    20250108      0
# 166      ecmf      2t     heightAboveGround    2    20250108      0
# 167      ecmf      2t     heightAboveGround    2    20250108      0
# 168      ecmf      2t     heightAboveGround    2    20250108      0
# 169      ecmf      2t     heightAboveGround    2    20250108      0
# 170      ecmf      tp               surface    0    20250108      0
# 171      ecmf      tp               surface    0    20250108      0
# 172      ecmf      2t     heightAboveGround    2    20250108      0
# 173      ecmf      tp               surface    0    20250108      0
# 174      ecmf      tp               surface    0    20250108      0
# 175      ecmf      tp               surface    0    20250108      0
# 176      ecmf      tp               surface    0    20250108      0
# 177      ecmf      2t     heightAboveGround    2    20250108      0
# 178      ecmf      2t     heightAboveGround    2    20250108      0
# 179      ecmf      tp               surface    0    20250108      0
# 180      ecmf      2t     heightAboveGround    2    20250108      0
# 181      ecmf      2t     heightAboveGround    2    20250108      0
# 182      ecmf      2t     heightAboveGround    2    20250108      0
# 183      ecmf      tp               surface    0    20250108      0
# 184      ecmf      tp               surface    0    20250108      0
# 185      ecmf      tp               surface    0    20250108      0
# 186      ecmf      2t     heightAboveGround    2    20250108      0
# 187      ecmf      tp               surface    0    20250108      0
# 188      ecmf      tp               surface    0    20250108      0
# 189      ecmf      2t     heightAboveGround    2    20250108      0
# 190      ecmf      2t     heightAboveGround    2    20250108      0
# 191      ecmf      tp               surface    0    20250108      0
# 192      ecmf      2t     heightAboveGround    2    20250108      0
# 193      ecmf      2t     heightAboveGround    2    20250108      0
# 194      ecmf      2t     heightAboveGround    2    20250108      0
# 195      ecmf      2t     heightAboveGround    2    20250108      0
# 196      ecmf      2t     heightAboveGround    2    20250108      0
# 197      ecmf      2t     heightAboveGround    2    20250108      0
# 198      ecmf      2t     heightAboveGround    2    20250108      0
# 199      ecmf      tp               surface    0    20250108      0
# 200      ecmf      tp               surface    0    20250108      0
# 201      ecmf      tp               surface    0    20250108      0
# 202      ecmf      tp               surface    0    20250108      0
# 203      ecmf      tp               surface    0    20250108      0
#
#         stepRange dataType number   gridType
# Message
# 0          0-21      pf      14    regular_ll
# 1            21      pf      22    regular_ll
# 2          0-21      pf      23    regular_ll
# 3            21      pf      31    regular_ll
# 4            21      pf      40    regular_ll
# 5          0-21      pf      50    regular_ll
# 6          0-21      pf      41    regular_ll
# 7          0-21      pf      32    regular_ll
# 8            21      pf      13    regular_ll
# 9            21      pf       5    regular_ll
# 10         0-21      pf      15    regular_ll
# 11         0-21      pf      24    regular_ll
# 12         0-21      pf      33    regular_ll
# 13         0-21      pf      42    regular_ll
# 14         0-21      pf       6    regular_ll
# 15           21      pf      50    regular_ll
# 16           21      pf      41    regular_ll
# 17           21      pf      23    regular_ll
# 18           21      pf      14    regular_ll
# 19           21      pf      32    regular_ll
# 20         0-21      pf      34    regular_ll
# 21         0-21      pf       7    regular_ll
# 22         0-21      pf      25    regular_ll
# 23         0-21      pf      16    regular_ll
# 24         0-21      pf      43    regular_ll
# 25           21      pf      24    regular_ll
# 26         0-21      pf      26    regular_ll
# 27         0-21      pf      17    regular_ll
# 28         0-21      pf      35    regular_ll
# 29           21      pf      42    regular_ll
# 30           21      pf       6    regular_ll
# 31           21      pf      15    regular_ll
# 32           21      pf      33    regular_ll
# 33         0-21      pf       8    regular_ll
# 34         0-21      pf      44    regular_ll
# 35         0-21      pf      18    regular_ll
# 36         0-21      pf       9    regular_ll
# 37         0-21      pf      27    regular_ll
# 38           21      pf       7    regular_ll
# 39         0-21      pf      45    regular_ll
# 40         0-21      pf      36    regular_ll
# 41           21      pf      16    regular_ll
# 42           21      pf      43    regular_ll
# 43           21      pf      34    regular_ll
# 44           21      pf      25    regular_ll
# 45           21      pf      44    regular_ll
# 46           21      pf       8    regular_ll
# 47           21      pf      17    regular_ll
# 48           21      pf      26    regular_ll
# 49         0-21      pf      19    regular_ll
# 50           21      pf      35    regular_ll
# 51         0-21      pf       1    regular_ll
# 52         0-21      pf      28    regular_ll
# 53         0-21      cf       0    regular_ll
# 54         0-21      pf      37    regular_ll
# 55         0-21      pf      46    regular_ll
# 56           21      pf      27    regular_ll
# 57           21      pf      18    regular_ll
# 58           21      pf      45    regular_ll
# 59           21      pf      36    regular_ll
# 60           21      pf       9    regular_ll
# 61           21      pf       1    regular_ll
# 62         0-21      pf       2    regular_ll
# 63         0-21      pf      38    regular_ll
# 64           21      pf      37    regular_ll
# 65           21      pf      28    regular_ll
# 66           21      cf       0    regular_ll
# 67           21      pf      19    regular_ll
# 68         0-21      pf      29    regular_ll
# 69           21      pf      46    regular_ll
# 70         0-21      pf      10    regular_ll
# 71         0-21      pf      47    regular_ll
# 72         0-21      pf      11    regular_ll
# 73         0-21      pf       3    regular_ll
# 74         0-21      pf      48    regular_ll
# 75         0-21      pf      20    regular_ll
# 76           21      pf      38    regular_ll
# 77           21      pf      29    regular_ll
# 78           21      pf      10    regular_ll
# 79         0-21      pf      39    regular_ll
# 80           21      pf      47    regular_ll
# 81           21      pf       2    regular_ll
# 82         0-21      pf      49    regular_ll
# 83         0-21      pf       4    regular_ll
# 84           21      pf      21    regular_ll
# 85           21      pf      48    regular_ll
# 86         0-21      pf      30    regular_ll
# 87           21      pf      20    regular_ll
# 88           21      pf      39    regular_ll
# 89         0-21      pf      12    regular_ll
# 90           21      pf       4    regular_ll
# 91           21      pf      11    regular_ll
# 92         0-21      pf      21    regular_ll
# 93           21      pf      49    regular_ll
# 94           21      pf      12    regular_ll
# 95           21      pf       3    regular_ll
# 96           21      pf      30    regular_ll
# 97         0-21      pf       5    regular_ll
# 98         0-21      pf      13    regular_ll
# 99         0-21      pf      22    regular_ll
# 100        0-21      pf      40    regular_ll
# 101        0-21      pf      31    regular_ll
# 102        0-24      pf      14    regular_ll
# 103          24      pf      40    regular_ll
# 104        0-24      pf      41    regular_ll
# 105        0-24      pf      23    regular_ll
# 106          24      pf      13    regular_ll
# 107        0-24      pf      32    regular_ll
# 108        0-24      pf      50    regular_ll
# 109          24      pf      31    regular_ll
# 110          24      pf      22    regular_ll
# 111          24      pf       5    regular_ll
# 112        0-24      pf      33    regular_ll
# 113        0-24      pf      42    regular_ll
# 114        0-24      pf      15    regular_ll
# 115        0-24      pf      24    regular_ll
# 116        0-24      pf       6    regular_ll
# 117        0-24      pf       7    regular_ll
# 118          24      pf      50    regular_ll
# 119          24      pf      41    regular_ll
# 120        0-24      pf      25    regular_ll
# 121          24      pf      23    regular_ll
# 122        0-24      pf      34    regular_ll
# 123        0-24      pf      16    regular_ll
# 124          24      pf      32    regular_ll
# 125        0-24      pf      43    regular_ll
# 126          24      pf      14    regular_ll
# 127          24      pf      42    regular_ll
# 128          24      pf      15    regular_ll
# 129        0-24      pf      35    regular_ll
# 130          24      pf       6    regular_ll
# 131        0-24      pf      26    regular_ll
# 132        0-24      pf      44    regular_ll
# 133          24      pf      24    regular_ll
# 134        0-24      pf      17    regular_ll
# 135        0-24      pf       8    regular_ll
# 136          24      pf      33    regular_ll
# 137        0-24      pf       9    regular_ll
# 138        0-24      pf      45    regular_ll
# 139        0-24      pf      27    regular_ll
# 140          24      pf       7    regular_ll
# 141          24      pf      25    regular_ll
# 142          24      pf      43    regular_ll
# 143        0-24      pf      18    regular_ll
# 144          24      pf      34    regular_ll
# 145        0-24      pf      36    regular_ll
# 146          24      pf      16    regular_ll
# 147          24      pf      44    regular_ll
# 148          24      pf       8    regular_ll
# 149          24      pf      26    regular_ll
# 150          24      pf      35    regular_ll
# 151        0-24      pf      37    regular_ll
# 152          24      pf      17    regular_ll
# 153        0-24      pf      19    regular_ll
# 154        0-24      cf       0    regular_ll
# 155        0-24      pf       1    regular_ll
# 156          24      pf      36    regular_ll
# 157        0-24      pf      46    regular_ll
# 158        0-24      pf      28    regular_ll
# 159          24      pf      18    regular_ll
# 160          24      pf       9    regular_ll
# 161          24      pf      45    regular_ll
# 162          24      pf      27    regular_ll
# 163        0-24      pf      47    regular_ll
# 164          24      cf       0    regular_ll
# 165        0-24      pf      10    regular_ll
# 166          24      pf      37    regular_ll
# 167          24      pf       1    regular_ll
# 168          24      pf      19    regular_ll
# 169          24      pf      28    regular_ll
# 170        0-24      pf      38    regular_ll
# 171        0-24      pf      29    regular_ll
# 172          24      pf      46    regular_ll
# 173        0-24      pf       2    regular_ll
# 174        0-24      pf      48    regular_ll
# 175        0-24      pf       3    regular_ll
# 176        0-24      pf      20    regular_ll
# 177          24      pf      10    regular_ll
# 178          24      pf      29    regular_ll
# 179        0-24      pf      11    regular_ll
# 180          24      pf      38    regular_ll
# 181          24      pf      47    regular_ll
# 182          24      pf       2    regular_ll
# 183        0-24      pf      39    regular_ll
# 184        0-24      pf      21    regular_ll
# 185        0-24      pf       4    regular_ll
# 186          24      pf      20    regular_ll
# 187        0-24      pf      12    regular_ll
# 188        0-24      pf      30    regular_ll
# 189          24      pf      39    regular_ll
# 190          24      pf      11    regular_ll
# 191        0-24      pf      49    regular_ll
# 192          24      pf      48    regular_ll
# 193          24      pf       3    regular_ll
# 194          24      pf       4    regular_ll
# 195          24      pf      49    regular_ll
# 196          24      pf      12    regular_ll
# 197          24      pf      21    regular_ll
# 198          24      pf      30    regular_ll
# 199        0-24      pf      22    regular_ll
# 200        0-24      pf      40    regular_ll
# 201        0-24      pf      13    regular_ll
# 202        0-24      pf      31    regular_ll
# 203        0-24      pf       5    regular_ll

# %%
t2m = data.select(shortName='2t',step=24)
t2m.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>2t</th><td style='text-align: left;'>heightAboveGround</td><td style='text-align: left;'>2</td><td style='text-align: left;'>20250108</td><td style='text-align: left;'>0</td><td style='text-align: left;'>24</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>167</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# To calculate the probability of 2m temperature being lower than 0°C and total precipitation being greater than 1 mm (0.001 m), we need to mask where these conditions are filled for each ensemble member.
# First we make an empty fieldset object, and then we append each mask field to it.
# Finally we can calculate the probability by calculating mean of this fieldset and multiplying by 100.
#
# One aditional step we need to do here is to calculate the total precipitation between steps 21 and 24, because the raw data has the total precipitation accumulated from the start of the forecast.

# %%
mask = mv.Fieldset()
for number in range(51):
    t2m_n = t2m.select(number = number,)
    tp_24 = data.select(shortName='tp',step=24, number = number)
    tp_21 = data.select(shortName='tp',step=21, number = number)
    tp_n = tp_24 - tp_21
    m = (t2m_n <= 273.15) & (tp_n >= 0.001)
    mask.append(m)

prob = (mv.mean(mask))*100

# %% [markdown]
# ## Plotting the data
# And finally, we can plot the data on the map.

# %%
# define coastlines
coast = mv.mcoast(
    map_coastline_colour="charcoal",
    map_coastline_resolution="medium",
    map_coastline_land_shade="on",
    map_coastline_land_shade_colour="cream",
    map_coastline_sea_shade="off",
    map_boundaries="on",
    map_boundaries_colour= "charcoal",
    map_boundaries_thickness = 1,
    map_disputed_boundaries = "off",
    map_grid_colour="tan",
    map_label_height=0.35,
)

# define view
view = mv.geoview(
    area_mode="name",
    area_name="europe",
    coastlines=coast
)

#define styles
prob_shade = mv.mcont(legend= "on",
                contour_automatics_settings = "style_name",
                contour_style_name = "sh_blup_f0t100lst")

title = mv.mtext(
    text_lines=["Combined probabilities: 2m Temperature < 0C and total precipitation > 1 mm", 
           "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H'/> ",
           "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H'/>, STEP: <grib_info key='step' />"],
    text_font_size=0.4,
    text_colour         = 'charcoal')

ecmwf_text = mv.mtext(    
    text_lines          = ["© European Centre for Medium-Range Weather Forecasts (ECMWF)",
                           "Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use",
                            "https://apps.ecmwf.int/datasets/licences/general/"],
    text_justification  = 'center',
    text_font_size      = 0.3,
    text_mode           = "positional",
    text_box_x_position = 6.,
    text_box_y_position = -0.2,
    text_box_x_length   = 8,
    text_box_y_length   = 2,
    text_colour         = 'charcoal')

# generate plot
mv.setoutput('jupyter', plot_widget=False)
mv.plot(view, prob, prob_shade, title, ecmwf_text)

# %% [markdown]
# To generate the png file you can run the following cell.

# %%
png = mv.png_output(
      output_name = "medium-ens-tp-2t",   # specify relative or full path
      output_title = "medium-ens-tp-2t",    # title used by a viewer
      output_width = 1000,                 # set width in pixels
)
mv.setoutput(png)
mv.plot(view, prob, prob_shade, title, ecmwf_text)

# %% [markdown]
# Note that plot produced using open data dataset will slightly differ from one from Open Charts. This is due to different resolution of the data.
# Open data is on 0.25x0.25 resolution, while high resolution data is 0.1x0.1 grid.
