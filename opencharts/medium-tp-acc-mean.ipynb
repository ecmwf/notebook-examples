# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>
#
# # 	Ensemble mean for total accumulated precipitation

# %% [markdown]
# This notebook will provide you guidance how to explore and plot ECMWF open dataset to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://apps.ecmwf.int/webapps/opencharts/products/medium-tp-acc-mean

# %% [markdown]
# The full list of available Open data products can be found [here](https://www.ecmwf.int/en/forecasts/datasets/open-data), and more information can be found in the [User documentation](https://confluence.ecmwf.int/display/UDOC/ECMWF+Open+Data+-+Real+Time).
#
# Access to ECMWF Open data is governed by the Creative Commons CC-BY-4.0 licence and associated [Terms of Use](https://apps.ecmwf.int/datasets/licences/general/).
#
# <sub> In applying this licence, ECMWF does not waive the privileges and immunities granted to it by virtue of its status as an intergovernmental organisation nor does it submit to any jurisdiction </sub>
#
# To find out how to obtain the access to the full forecast dataset at higher resolution please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input parameter:
#
# * [Total precipitation](https://apps.ecmwf.int/codes/grib/param-db/?id=228)

# %% [markdown]
# In this example, we will use:
# - **ecmwf.opendata** Client to download the data
# - **ecmwf.data** library to read and process the data (calculate the speed and probabilities)
# - **ecmwf.geomaps** to plot the result

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#import sys
#!{sys.executable} -m pip install ecmwf-data ecmwf-opendata git+https://github.com/ecmwf/ecmwf-geomaps.git

# %%
import ecmwf.data as ecdata
from ecmwf.geomaps import GeoMap
from ecmwf.opendata import Client

# %%
client = Client("ecmwf", beta=True)

# %%
parameters = ['tp']
filename = 'medium-tp-acc-mean.grib'
filename
# Out:
# 'medium-tp-acc-mean.grib'

# %% [markdown]
# To calculate the mean of total accumulated precipitation, we need to retrieve all the ensemble members at the given time.
# Setting the **type** to **ef** will download all 50 ensemble members as well as the control forecast.

# %%
client.retrieve(
    date=-2,
    time=0,
    step=240,
    stream="enfo",
    type="ef",
    levtype="sfc",
    param=parameters,
    target=filename
)
# Out:
# {'date': '-2', 'time': '0', 'step': '240', 'stream': 'enfo', 'type': 'ef', 'resol': '0p4-beta', '_url': 'https://ai4edataeuwest.blob.core.windows.net/ecmwf', 'extension': 'grib2'}
# {'levtype': ['sfc'], 'param': ['tp'], 'step': ['240'], 'type': ['cf', 'pf']}

# %%
data = ecdata.read(filename)

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
#
#                 <table>
#                 <tr><th>parameter</th><th>typeOfLevel</th><th>level</th><th>date</th><th>time</th><th>step</th><th>number</th><th>paramId</th><th>class</th><th>stream</th><th>type</th><th>experimentVersionNumber</th></tr>
#                 <tr><th style='text-align: right;'>tp</th><td style='text-align: left;'>surface</td><td style='text-align: left;'>0</td><td style='text-align: left;'>20220116</td><td style='text-align: left;'>0</td><td style='text-align: left;'>240</td><td style='text-align: left;'>0,1,...</td><td style='text-align: left;'>228228</td><td style='text-align: left;'>od</td><td style='text-align: left;'>enfo</td><td style='text-align: left;'>cf,pf</td><td style='text-align: left;'>0001</td></tr>
#                 </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#         centre shortName typeOfLevel  level  dataDate  dataTime stepRange  \
# Message
# 0        ecmf      tp       surface     0    20220116      0        240
# 1        ecmf      tp       surface     0    20220116      0        240
# 2        ecmf      tp       surface     0    20220116      0        240
# 3        ecmf      tp       surface     0    20220116      0        240
# 4        ecmf      tp       surface     0    20220116      0        240
# 5        ecmf      tp       surface     0    20220116      0        240
# 6        ecmf      tp       surface     0    20220116      0        240
# 7        ecmf      tp       surface     0    20220116      0        240
# 8        ecmf      tp       surface     0    20220116      0        240
# 9        ecmf      tp       surface     0    20220116      0        240
# 10       ecmf      tp       surface     0    20220116      0        240
# 11       ecmf      tp       surface     0    20220116      0        240
# 12       ecmf      tp       surface     0    20220116      0        240
# 13       ecmf      tp       surface     0    20220116      0        240
# 14       ecmf      tp       surface     0    20220116      0        240
# 15       ecmf      tp       surface     0    20220116      0        240
# 16       ecmf      tp       surface     0    20220116      0        240
# 17       ecmf      tp       surface     0    20220116      0        240
# 18       ecmf      tp       surface     0    20220116      0        240
# 19       ecmf      tp       surface     0    20220116      0        240
# 20       ecmf      tp       surface     0    20220116      0        240
# 21       ecmf      tp       surface     0    20220116      0        240
# 22       ecmf      tp       surface     0    20220116      0        240
# 23       ecmf      tp       surface     0    20220116      0        240
# 24       ecmf      tp       surface     0    20220116      0        240
# 25       ecmf      tp       surface     0    20220116      0        240
# 26       ecmf      tp       surface     0    20220116      0        240
# 27       ecmf      tp       surface     0    20220116      0        240
# 28       ecmf      tp       surface     0    20220116      0        240
# 29       ecmf      tp       surface     0    20220116      0        240
# 30       ecmf      tp       surface     0    20220116      0        240
# 31       ecmf      tp       surface     0    20220116      0        240
# 32       ecmf      tp       surface     0    20220116      0        240
# 33       ecmf      tp       surface     0    20220116      0        240
# 34       ecmf      tp       surface     0    20220116      0        240
# 35       ecmf      tp       surface     0    20220116      0        240
# 36       ecmf      tp       surface     0    20220116      0        240
# 37       ecmf      tp       surface     0    20220116      0        240
# 38       ecmf      tp       surface     0    20220116      0        240
# 39       ecmf      tp       surface     0    20220116      0        240
# 40       ecmf      tp       surface     0    20220116      0        240
# 41       ecmf      tp       surface     0    20220116      0        240
# 42       ecmf      tp       surface     0    20220116      0        240
# 43       ecmf      tp       surface     0    20220116      0        240
# 44       ecmf      tp       surface     0    20220116      0        240
# 45       ecmf      tp       surface     0    20220116      0        240
# 46       ecmf      tp       surface     0    20220116      0        240
# 47       ecmf      tp       surface     0    20220116      0        240
# 48       ecmf      tp       surface     0    20220116      0        240
# 49       ecmf      tp       surface     0    20220116      0        240
# 50       ecmf      tp       surface     0    20220116      0        240
#
#         dataType number   gridType
# Message
# 0          pf      27    regular_ll
# 1          pf      41    regular_ll
# 2          pf      47    regular_ll
# 3          pf      21    regular_ll
# 4          pf       4    regular_ll
# 5          pf      50    regular_ll
# 6          pf      49    regular_ll
# 7          pf      38    regular_ll
# 8          pf      16    regular_ll
# 9          pf      45    regular_ll
# 10         pf      12    regular_ll
# 11         pf      36    regular_ll
# 12         pf      25    regular_ll
# 13         pf      43    regular_ll
# 14         pf      34    regular_ll
# 15         pf      23    regular_ll
# 16         pf       9    regular_ll
# 17         pf       7    regular_ll
# 18         pf      29    regular_ll
# 19         pf      30    regular_ll
# 20         pf      18    regular_ll
# 21         pf      32    regular_ll
# 22         pf      14    regular_ll
# 23         pf       2    regular_ll
# 24         pf      33    regular_ll
# 25         pf      26    regular_ll
# 26         pf      20    regular_ll
# 27         pf      22    regular_ll
# 28         pf      39    regular_ll
# 29         pf      24    regular_ll
# 30         pf      46    regular_ll
# 31         pf      28    regular_ll
# 32         pf      44    regular_ll
# 33         pf      31    regular_ll
# 34         pf      17    regular_ll
# 35         pf       5    regular_ll
# 36         pf       3    regular_ll
# 37         pf       6    regular_ll
# 38         pf      48    regular_ll
# 39         pf      42    regular_ll
# 40         pf       8    regular_ll
# 41         pf      19    regular_ll
# 42         pf      40    regular_ll
# 43         pf      10    regular_ll
# 44         pf      15    regular_ll
# 45         pf      37    regular_ll
# 46         pf      35    regular_ll
# 47         pf      11    regular_ll
# 48         pf       1    regular_ll
# 49         pf      13    regular_ll
# 50         cf       0    regular_ll

# %% [markdown]
# We can simply calculate the mean of all the ensemble members:

# %%
mean_tp = ecdata.mean(data)

# %% [markdown]
# And finally, we can plot the data on the map.

# %%
fig = GeoMap(area_name='europe', preset='background-foreground')

fig.contour_lines(mean_tp, preset="accumulated_tp_3")
fig.title(["Ensemble mean for total accumulated precipitation", 
          "START TIME: <grib_info key='base-date' format='%a %d %B %Y %H' />",
          "VALID TIME: <grib_info key='valid-date' format='%a %d %B %Y %H' />, STEP: <grib_info key='step' />"])
fig.legend()

fig.show()
