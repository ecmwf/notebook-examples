# %% [markdown]
# # Mollweide projection
#
# This is one cell notebook example that will help you set Mollweide projection using Magics.
#
# At ECMWF
#
# #### From your workstation:
# module swap (or load) Magics/new
# jupyter notebook
#
# load this notebook

# %% [markdown]
# **Magics** supports several different projections, and they are controled using **mmap** funciton.
#
# List of all **mmap** parameters and projections you can find [in Magics documentation](https://confluence.ecmwf.int/display/MAGP/Subpage+-+Projection "Projection parameters").

# %%
import Magics.macro as magics

# Setting the projection
projection = magics.mmap(
    subpage_map_projection        = "mollweide",
    subpage_map_area_definition   = "full",
    subpage_frame                 = "off",
    page_frame                    = "off",
    page_id_line                   = "off")

# Defining the coastlines
coast = magics.mcoast(
    map_coastline_colour            = "grey",
    map_coastline_land_shade        = "on", 
    map_coastline_land_shade_colour =  "cream", 
    map_grid                        = "on", 
    map_grid_colour                 = "grey", 
    map_coastline_sea_shade         = "on", 
    map_coastline_sea_shade_colour  =  "white", 
    map_label                       ="off")

magics.plot(projection, coast)
