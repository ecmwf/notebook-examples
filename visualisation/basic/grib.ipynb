# %%
from Magics import macro as magics

data = magics.mgrib(grib_input_file_name= "2t.grib")
contour = magics.mcont(contour_automatic_setting = 'ecmwf', legend='on')
legend = magics.mlegend(legend_display_type = "continuous", 
                        legend_text_height=0.75,
                        legend_text_colour ='navy')
magics.plot(data, contour, legend, magics.mcoast())

# %%
import cfgrib

# %%
ds = cfgrib.open_file('2t.grib')

# %%
print (ds)
# Out:
# Dataset(dimensions=OrderedDict([('i', 6599680)]), variables=OrderedDict([('t2m', Variable(dimensions=('i',), data=OnDiskArray(stream=FileStream(path='2t.grib', errors='ignore'), shape=(6599680,), missing_value=9999))), ('number', Variable(dimensions=(), data=0)), ('time', Variable(dimensions=(), data=1491048000)), ('step', Variable(dimensions=(), data=0.0)), ('surface', Variable(dimensions=(), data=0)), ('latitude', Variable(dimensions=('i',), data=array([ 89.94618772,  89.94618772,  89.94618772, ..., -89.94618772,
#        -89.94618772, -89.94618772]))), ('longitude', Variable(dimensions=('i',), data=array([  0.,  18.,  36., ..., 306., 324., 342.]))), ('valid_time', Variable(dimensions=(), data=1491048000.0))]), attributes=OrderedDict([('GRIB_edition', 1), ('GRIB_centre', 'ecmf'), ('GRIB_centreDescription', 'European Centre for Medium-Range Weather Forecasts'), ('GRIB_subCentre', 0), ('history', "GRIB to CDM+CF via cfgrib-0.9.2/ecCodes-2.9.0 with source='2t.grib', filter_by_keys={}, encode_parameter=True, encode_time=True, encode_vertical=True, encode_geography=True")]), encoding={'source': '2t.grib', 'filter_by_keys': {}, 'encode_parameter': True, 'encode_time': True, 'encode_vertical': True, 'encode_geography': True})

# %%
data = magics.xarray(ds, xarray_variable_name = 't2m')
magics.plot(data, mcont(), mcoast())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9a2611cb41ed> in <module>
# ----> 1 data = magics.xarray(ds, xarray_variable_name = 't2m')
#       2 magics.plot(data, mcont(), mcoast())
#
# AttributeError: module 'Magics.macro' has no attribute 'xarray'
