# %% [markdown]
# This example will help you to to set up a geographical view on polar stereographic  projection.
# You can change the view playing with the values for *subpage_lower_left_latitude*,  *subpage_lower_left_longitude*, *subpage_upper_right_latitude* and *subpage_upper_right_longitude*

# %%
from Magics import macro as magics

# %%
#Setting the coordinates of the geographical area
projection = magics.mmap(
		subpage_upper_right_longitude = 68.0, 
        subpage_upper_right_latitude =  50, 
        subpage_lower_left_longitude =  -15., 
        subpage_map_vertical_longitude =  0., 
        subpage_map_projection =  "polar_stereographic", 
        subpage_lower_left_latitude = 27.)

#Coastlines setting
coast = magics.mcoast( map_grid =  "on",
                map_grid_colour  =  "charcoal",
				map_coastline_land_shade  =  'on',
				map_coastline_land_shade_colour  =  'RGB(200, 200, 200)',
				map_coastline_colour =  "charcoal",
                map_coastline_resolution = "high",
		)

#Adding some text 
title = magics.mtext(
	  text_lines = ["<font size='1'>Europe on Polar Stereographic</font>"],
	  text_justification = "left",
	  text_font_size = 0.8,
	  text_colour = "charcoal")

#To the plot

magics.plot(projection, coast, title)

# %% [markdown]
# The coastlines object [*mcoast*](https://confluence.ecmwf.int/display/MAGP/Coastlines) comes with a long list of paremeters to customise the visualisation.

# %%
# coastlines
coast = magics.mcoast( map_grid =  "on",
                map_grid_colour  =  "charcoal",
                map_coastline_land_shade  =  'on',
                map_coastline_land_shade_colour  =  'grey',
                map_coastline_sea_shade  =  'on',
                map_coastline_sea_shade_colour  =  'RGB(0, 0, 120)',
                map_coastline_colour =  "charcoal",
                map_coastline_resolution = "high",
		)

magics.plot(projection, coast)
