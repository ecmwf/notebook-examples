# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <img src="data:image/png;base64,..." width="500px"/>
# </div>
#
# # 	MUCAPE and MUCIN

# %% [markdown]
# This notebook will provide you guidance how to explore ECMWF data to produce the map from the ECMWF open charts web product.
# The original product can be found on this link: https://charts.ecmwf.int/products/medium-cape-cin

# %% [markdown]
# <div class="output_png output_subarea output_execute_result">
# <center>
# <img src="data:image/png;base64,..."/></center>
# </div>

# %% [markdown]
# Some ECMWF real-time products are governed by the [ECMWF Standard Licence Agreement](https://www.ecmwf.int/sites/default/files/ECMWF_Standard_Licence.pdf) and are not free or open. Access to these products depends on your use case. To find out which licence applies to you, please visit: [Use cases and licence conditions page](https://www.ecmwf.int/en/forecasts/accessing-forecasts/licences-available).
#
# To find out how to obtain the access to the ECMWF forecast data please visit our [Access page](https://www.ecmwf.int/en/forecasts/accessing-forecasts).

# %% [markdown]
# ## Retrieve Data
# This product takes in input parameters:
#
# * [Most-unstable CAPE](https://codes.ecmwf.int/grib/param-db/228235)
# * [Most-unstable CIN](https://codes.ecmwf.int/grib/param-db/228236)

# %% [markdown]
# In this example, we will use:
# - [**ecmwf-api-client**](https://pypi.org/project/ecmwf-api-client/) to download the data
# - [**Metview**](https://metview.readthedocs.io/en/latest/) library to read, process and plot the data

# %% [markdown]
# First we need to install them in the current Jupyter kernel:
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you are running the notebook on MyBinder or already have the libraries installed, go directly to importing the libraries.
# </div>
# <div class="alert alert-block alert-info">
# <b>Note:</b> If you don't have these libraries installed, click on three dots below, uncomment the code and run the next cell.
# </div>

# %%
#!pip install ecmwf-api-client metview metview-python

# %%
import earthkit.data as ekd
import earthkit.plots as ekp
import requests

# %%
filename = 'medium-cape-cin.grib'

# %%
data = ekd.from_source("mars",
    {
    "class": "od",
    "date": -1,
    "expver": "1",
    "levtype": "sfc",
    "param": "228235/228236",
    "step": "12",
    "stream": "oper",
    "time": "00",
    "type": "fc",
    "grid": "0.25/0.25"
    },)

# %%
data.ls()
# Out:
#   centre shortName         typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf    mucape  mostUnstableParcel      0  20250727         0        12
# 1   ecmf     mucin  mostUnstableParcel      0  20250727         0        12
#
#   dataType number    gridType
# 0       fc   None  regular_ll
# 1       fc   None  regular_ll

# %% [markdown]
# If you already have the access to the ECMWF archived forecast data, you can use the next cell to download data from the [MARS archive](https://confluence.ecmwf.int/display/UDOC/MARS+user+documentation):

# %% [markdown]
# Alternatively we have prepared small sample dataset to explore

# %%
url = f"https://sites.ecmwf.int/repository/opencharts-sample-data/{filename}"
data = ekd.from_source("url",url)

# %% [markdown]
# ## Exploring the data
# Now we can use **earthkit.data** to explore our data.

# %% [markdown]
# The **describe()** function will give us the overview of the dataset.

# %%
data.describe()
# Out:
# <style type="text/css">
# #T_49c3a th {
#   text-align: left;
# }
# #T_49c3a_row0_col0, #T_49c3a_row0_col1, #T_49c3a_row0_col2, #T_49c3a_row0_col3, #T_49c3a_row0_col4, #T_49c3a_row0_col5, #T_49c3a_row0_col6, #T_49c3a_row0_col7, #T_49c3a_row0_col8, #T_49c3a_row0_col9, #T_49c3a_row1_col0, #T_49c3a_row1_col1, #T_49c3a_row1_col2, #T_49c3a_row1_col3, #T_49c3a_row1_col4, #T_49c3a_row1_col5, #T_49c3a_row1_col6, #T_49c3a_row1_col7, #T_49c3a_row1_col8, #T_49c3a_row1_col9 {
#   text-align: left;
# }
# </style>
# <table id="T_49c3a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49c3a_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_49c3a_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_49c3a_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_49c3a_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_49c3a_level0_col4" class="col_heading level0 col4" >number</th>
#       <th id="T_49c3a_level0_col5" class="col_heading level0 col5" >paramId</th>
#       <th id="T_49c3a_level0_col6" class="col_heading level0 col6" >class</th>
#       <th id="T_49c3a_level0_col7" class="col_heading level0 col7" >stream</th>
#       <th id="T_49c3a_level0_col8" class="col_heading level0 col8" >type</th>
#       <th id="T_49c3a_level0_col9" class="col_heading level0 col9" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49c3a_level0_row0" class="row_heading level0 row0" >cin</th>
#       <th id="T_49c3a_level1_row0" class="row_heading level1 row0" >surface</th>
#       <td id="T_49c3a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_49c3a_row0_col1" class="data row0 col1" >20220223</td>
#       <td id="T_49c3a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_49c3a_row0_col3" class="data row0 col3" >12</td>
#       <td id="T_49c3a_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_49c3a_row0_col5" class="data row0 col5" >228001</td>
#       <td id="T_49c3a_row0_col6" class="data row0 col6" >od</td>
#       <td id="T_49c3a_row0_col7" class="data row0 col7" >oper</td>
#       <td id="T_49c3a_row0_col8" class="data row0 col8" >fc</td>
#       <td id="T_49c3a_row0_col9" class="data row0 col9" >0001</td>
#     </tr>
#     <tr>
#       <th id="T_49c3a_level0_row1" class="row_heading level0 row1" >mucape</th>
#       <th id="T_49c3a_level1_row1" class="row_heading level1 row1" >mostUnstableParcel</th>
#       <td id="T_49c3a_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_49c3a_row1_col1" class="data row1 col1" >20220223</td>
#       <td id="T_49c3a_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_49c3a_row1_col3" class="data row1 col3" >12</td>
#       <td id="T_49c3a_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_49c3a_row1_col5" class="data row1 col5" >228235</td>
#       <td id="T_49c3a_row1_col6" class="data row1 col6" >od</td>
#       <td id="T_49c3a_row1_col7" class="data row1 col7" >oper</td>
#       <td id="T_49c3a_row1_col8" class="data row1 col8" >fc</td>
#       <td id="T_49c3a_row1_col9" class="data row1 col9" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# And an overview of one parameter, where we can see more information, such as units or type of level.

# %%
data.describe('mucape')
# Out:
# <style type="text/css">
# #T_59da2 th {
#   text-align: left;
# }
# #T_59da2_row0_col0, #T_59da2_row1_col0, #T_59da2_row2_col0, #T_59da2_row3_col0, #T_59da2_row4_col0, #T_59da2_row5_col0, #T_59da2_row6_col0, #T_59da2_row7_col0, #T_59da2_row8_col0, #T_59da2_row9_col0, #T_59da2_row10_col0, #T_59da2_row11_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_59da2">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59da2_level0_row0" class="row_heading level0 row0" >shortName</th>
#       <td id="T_59da2_row0_col0" class="data row0 col0" >mucape</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row1" class="row_heading level0 row1" >typeOfLevel</th>
#       <td id="T_59da2_row1_col0" class="data row1 col0" >mostUnstableParcel</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row2" class="row_heading level0 row2" >level</th>
#       <td id="T_59da2_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row3" class="row_heading level0 row3" >date</th>
#       <td id="T_59da2_row3_col0" class="data row3 col0" >20250727</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_59da2_row4_col0" class="data row4 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row5" class="row_heading level0 row5" >step</th>
#       <td id="T_59da2_row5_col0" class="data row5 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row6" class="row_heading level0 row6" >number</th>
#       <td id="T_59da2_row6_col0" class="data row6 col0" >None</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row7" class="row_heading level0 row7" >paramId</th>
#       <td id="T_59da2_row7_col0" class="data row7 col0" >228235</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row8" class="row_heading level0 row8" >class</th>
#       <td id="T_59da2_row8_col0" class="data row8 col0" >od</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row9" class="row_heading level0 row9" >stream</th>
#       <td id="T_59da2_row9_col0" class="data row9 col0" >oper</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row10" class="row_heading level0 row10" >type</th>
#       <td id="T_59da2_row10_col0" class="data row10 col0" >fc</td>
#     </tr>
#     <tr>
#       <th id="T_59da2_level0_row11" class="row_heading level0 row11" >experimentVersionNumber</th>
#       <td id="T_59da2_row11_col0" class="data row11 col0" >0001</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can use **ls()** function to list all the fields in the file we downloaded.

# %%
data.ls()
# Out:
#   centre shortName         typeOfLevel  level  dataDate  dataTime stepRange  \
# 0   ecmf    mucape  mostUnstableParcel      0  20250727         0        12
# 1   ecmf     mucin  mostUnstableParcel      0  20250727         0        12
#
#   dataType number    gridType
# 0       fc   None  regular_ll
# 1       fc   None  regular_ll

# %% [markdown]
# The grib file contains both parameters, and we will use the select() function to filter what we need.

# %%
mucape = data.sel(shortName= 'mucape')
mucin = data.sel(shortName= 'mucin')

# %% [markdown]
# ## Plotting the data
# And finally, we can plot the data on the map.

# %%
cape_style = ekp.styles.Style(
    colors=[
    '#0372fc',
    '#02bbfc',
    '#02fce3',
    '#04b3a6',
    '#02fc36',
    '#c4fc03',
    '#fc9402',
    '#fc1302',
    '#b1067d',
    '#ff00ff',
    '#8002fc'
],
    levels=[50, 100, 200, 400, 800, 1200, 1600, 2000, 2500, 3000, 4000, 9000],
    extend="max",
)

# %%
cin_style = ekp.styles.Style(
    colors=['#bfbfbfcc'],#( 0.75, 0.75, 0.75, 0.8)
    levels=[50,1100],
    legend_style='disjoint'
)

# %%
chart = ekp.Map(domain="Europe")

chart.land(color="#ffe2ab")

chart.contourf(mucape, style=cape_style, transform_first=True)
chart.contourf(mucin, style=cin_style, transform_first=True)

chart.legend(label='{variable_name}')

chart.title(
    "{variable_name!0} and {variable_name!1}\n"
    "START TIME: {base_time:%a %d %B %Y %H}\n"
    "VALID TIME: {valid_time:%a %d %B %Y %H} (T+{lead_time})",
    fontsize=11,
)

chart.coastlines(color="#333333")

chart.borders(color="#333333")
chart.gridlines(color="#665433")

chart.add_attribution("© European Centre for Medium-Range Weather Forecasts (ECMWF)\n" 
                      "Source: www.ecmwf.int Licence: CC-BY-4.0 and ECMWF Terms of Use\n"
                      "https://apps.ecmwf.int/datasets/licences/general/")

chart.add_logo("ecmwf")

#chart.show()
chart.save(fname = f'{filename}.png')

# %%
r, g, b = 0.8000, 0.3309, 0.2000
hex_colour = '#{:02x}{:02x}{:02x}'.format(int(r*255), int(g*255), int(b*255))
hex_colour
# Out:
# '#cc5433'

# %% [markdown]
# Note that plot produced using this dataset will slightly differ from one from Open Charts. This is due to different resolution of the data.
# The data used here is on 0.25x0.25 resolution, while high resolution data is 0.1x0.1 grid.
